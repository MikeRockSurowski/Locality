# %% [markdown]
# # Data Analysis
# [Check here](#Here)

# %% [markdown]
# # Basic imports

# %%
# basic python
import os
import re
import sys
import copy
import json
import warnings
from collections import namedtuple

### data analysis
import numpy as np
import pandas as pd
from scipy.stats import gmean

# compositional data analysis
import skbio.stats.composition as coda

### plotting
# matplotlib & seaborn
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.backends.backend_pdf import PdfPages # PDF generation
from matplotlib.patches import Ellipse

import seaborn as sns

# plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

### utils
from sklearn.utils.class_weight import compute_class_weight, compute_sample_weight

### figthing imbalance
from imblearn.over_sampling import SMOTENC

### Machine learning algorithms will be imported in the appropriate sections of this notebook

# %%
sns.set_theme(palette='colorblind', style='ticks')

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Functions

# %%
def plot_confidence_ellipse(ax, data, n_std=2.0, facecolor='none', **kwargs):
   
    if data.shape[0] < 2:
        return

    cov = np.cov(data.T)
    mean = np.mean(data, axis=0)

    # Eigenvectors and eigenvalues (rotation and scale of ellipse)
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    vals = vals[order]
    vecs = vecs[:, order]

    angle = np.degrees(np.arctan2(*vecs[:, 0][::-1]))
    width, height = 2 * n_std * np.sqrt(vals)

    ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle,
                      facecolor=facecolor, **kwargs)
    ax.add_patch(ellipse)

# %%
def ellipses_95_confidence(x, y, data, group_col, palette, group_order=None, ax=None):

    if group_order:
        groups = group_order
    else:
        groups = data[group_col].unique().tolist()
    
    for group_name, color in zip(groups, palette):
        group_df = data[data['Locality'] == group_name]
        points = group_df[[x, y]].values
        
        if ax is None:
            ax = plt.gca()
        
        plot_confidence_ellipse(ax, points, edgecolor=color, n_std=2)

# %%
def sample_prediction(test_y, pred_y, index_label=['SampleID', 'Line']):
    
    df = pd.DataFrame()
    
    df['Value'] = test_y
    df['Prediction'] = pred_y
    df['PredictionAccuracy'] = df.Value == df.Prediction
    
    pred_acc = df['PredictionAccuracy'].groupby(index_label).sum() / df['PredictionAccuracy'].groupby(index_label).count()
    
    return pred_acc

# %%
def grid_results_view(grid):
    
    res = pd.DataFrame(grid.cv_results_)
    res.dropna(subset=['split0_test_score', 'std_test_score'], inplace=True)
    res.sort_values("rank_test_score", inplace=True)
    
    return res

# %%
def prediction_accuracy_frame(test_y, pred_y, index_label=['SampleID', 'Line']):
    
    pred_y = pd.Series(pred_y, index=test_y.index)
    pred_mode = pred_y.groupby(index_label).agg(pd.Series.mode)
    pred_mode.rename('PredictionMode', inplace=True)

    pred_acc = sample_prediction(test_y, pred_y, index_label=index_label)
    
    pred_results_frame = pd.concat([test_y.groupby(index_label).max(), pred_mode, pred_acc], axis=1)
    
    return pred_results_frame

# %%
def models_feats(zeros_to_nan=False, **models):
    feat_frame = pd.DataFrame()
    
    for name, model in models.items():
        keys = model.feature_names_in_
        
        if hasattr(model, 'coef_'):
            values = np.abs(model.coef_).sum(axis=0) / np.abs(model.coef_).sum()
            
        elif hasattr(model, 'feature_importances_'):
            values = model.feature_importances_
        
        else:
            raise TypeError('the model must have `coef_` or `feature_importances_` attribute')
        
        feats_vals = dict( zip ( keys, values ) )
        
        feat_frame[name] = feats_vals
    if zeros_to_nan:
        feat_frame = feat_frame.replace(0, np.nan)
        
    return feat_frame

# %%
def model_predictions(model, X_test, y_test):
    y_pred = model.predict(X_test)
    acc_score = accuracy_score(y_test, y_pred)
    predframe = prediction_accuracy_frame(y_test, y_pred)
    return y_pred, acc_score, predframe

# %%
def acc_meas(y_test, y_pred, print_res=True, return_vals=False):
    accu = accuracy_score(y_test, y_pred)
    f1_wgt = f1_score(y_test, y_pred, average='weighted')
    f1_mic = f1_score(y_test, y_pred, average='micro')
    
    if print_res:
        print('accuracy score:    {}'.format(accu))
        print('f1 weighted score: {}'.format(f1_wgt))
        print('f1 micro score:    {}'.format(f1_mic))
    
    if return_vals:
        res = {
            'accuracy' : accu,
            'f1_weighted' : f1_wgt,
            'f1_micro' : f1_mic
        }
        return res

# %%
def prob_classes(X, model, precision=4):
    prediction = model.predict_proba(X)
    prob_frame = pd.DataFrame(prediction, index=X.index, columns=model.classes_)
    if precision:
        prob_frame = prob_frame.round(precision)
        
    return prob_frame

# %%
idx = pd.IndexSlice

# %%
loadcsv = lambda file : pd.read_csv('Data/' + file, sep=';', index_col=[0, 1, 2, 3])

# %%
rareEarthsYttr = ["La", "Ce", "Pr", "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Y", "Er", "Tm", "Yb", "Lu"]

# %%
locdict = {
    'Altan Uul' : 'AUL',
    'Nemegt' : 'NEM',
    'Tsagan Khushuu' : 'TSK',
    'Toogreek' : 'TOG',
    'Bayan Dzak' : 'BDZ'
} # [locdict[i] for i in ALGORITHM.classes_]

# %%
lb_label_order = ['Bayan Dzak', 'Altan Uul', 'Nemegt', 'Tsagan Khushuu']
tb_label_order = ['Toogreek', 'Altan Uul', 'Nemegt', 'Tsagan Khushuu']

# %%
lb_label_acronym = [locdict[i] for i in lb_label_order]
tb_label_acronym = [locdict[i] for i in tb_label_order]

# %%
conf_mat_dict = {
    'logreg' : {},
    'forest' : {},
    'xboost' : {},
    'aboost' : {}
}

# %% [markdown]
# # Read and prepare frames

# %% [markdown]
# **Read the DataFrames**

# %%
ppm = loadcsv('ppmLODsfill.csv')
err = loadcsv('err.csv')
spot_info = loadcsv('spot_fullinfo.csv')

# %%
thin_sections = pd.read_csv('Data/ThinSections.csv', sep=';')

# %%
localities = spot_info.loc[:, 'Locality']
bones = spot_info.loc[:, 'Bone']

# %% [markdown]
# Fill the zeros

# %%
repl_dict = {}

for column in ppm.columns:
    ser = ppm[column]
    ser_larger_than_0 = ser[ser > 0]
    minimum_val = ser_larger_than_0.min()
    replacement = minimum_val / 10
    repl_dict[column] = { 0 : replacement}

# %%
ppm = ppm.replace(repl_dict)

# %%
ppm_closed = coda.closure(ppm)

# %%
alr_data = pd.DataFrame(
    data=coda.alr(ppm_closed),
    index=ppm.index,
    columns=ppm.columns[1:]
)

# %%
clr_data = pd.DataFrame(
    data=coda.clr(ppm_closed),
    index=ppm.index,
    columns=ppm.columns
)

# %%
ppm_nofills = loadcsv('ppm.csv')

# %%
idx = pd.IndexSlice

# %% [markdown]
# ## Train and test split

# %% [markdown]
# ### LB1 subset

# %%
train_lb1_samples = ['PR003', 'SF001', 'SF002', 'TS011', 'TS013', 'TS025', 'TS031', 'TS018', 'TS016', 'TS017', 'TF006']
test_lb1_samples = ['PR006', 'TS012', 'TS029', 'TS020', 'TS021', 'TS030', 'TS022']

lb1_train = alr_data.loc[idx[train_lb1_samples], :]
lb1_test = alr_data.loc[idx[test_lb1_samples], :]

locs_lb1_train = localities.loc[idx[train_lb1_samples], :]
locs_lb1_test = localities.loc[idx[test_lb1_samples], :]

# %% [markdown]
# ### LB2 subset

# %%
train_lb2_samples = ['PR003', 'SF001', 'SF002', 'TS011', 'TS013', 'TS025', 'TS031', 'TS018', 'TS016', 'TS017']
test_lb2_samples = ['PR006', 'TS012', 'TS029', 'TS020', 'TS021', 'TS030']

lb2_train = alr_data.loc[idx[train_lb2_samples], :]
lb2_test = alr_data.loc[idx[test_lb2_samples], :]

locs_lb2_train = localities.loc[idx[train_lb2_samples], :]
locs_lb2_test = localities.loc[idx[test_lb2_samples], :]

# %% [markdown]
# ### TB subset

# %%
train_trabecular_samples = ['TF029', 'TS015', 'PR002', 'TS024', 'TS026']
test_trabecular_samples = ['TS027', 'SF003', 'PR001', 'TF028']

tb_train = alr_data.loc[idx[train_trabecular_samples], :]
tb_test = alr_data.loc[idx[test_trabecular_samples], :]

locs_tb_train = localities.loc[idx[train_trabecular_samples], :]
locs_tb_test = localities.loc[idx[test_trabecular_samples], :]

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# Beginning with the subsetction [Logistic Regression](#Logistic-Regression), all the subsections regarding ML models here follow the same pattern:
# - Hyperparameters tuning in LB1 subset
# - Best parameters for LB1 subset
#   - Fitted model
#   - Accuracy measures
#   - Prediction for the whole samples
# - Hyperparameters tuning in LB2 subset
# - Best parameters for LB2 subset
#   - Fitted model
#   - Accuracy measures
#   - Prediction for the whole samples
# - Hyperparameters tuning in TB subset
# - Best parameters for TB subset
#   - Fitted model
#   - Accuracy measures
#   - Prediction for the whole samples

# %%
# machine learning

### model selection 
from sklearn.model_selection import GridSearchCV

### selecting features
from sklearn.feature_selection import SelectFromModel

### accuracy
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

# %%
lb2_results = pd.concat([ppm.loc[idx[test_lb2_samples], :], locs_lb2_test.rename('Locality'), spot_info.loc[idx[test_lb2_samples], 'mmDist']], axis=1)

# %%
ppm_long = ppm_nofills.melt(ignore_index=False, var_name='Element', value_name='PPM').merge(spot_info, left_index=True, right_index=True).reset_index()

# %%
ppm_long = ppm_long[ppm_long.Element != 'Ca']

# %%
ppm_summary = ppm_long.groupby(['Locality', 'Element']).describe()['PPM']
ppm_summary.to_excel('Describe.xlsx', merge_cells=False)

# %%
ppm_info = ppm.merge(spot_info[['Locality', 'Bone']], left_index=True, right_index=True)

# %%
ppm_locs_group = ppm_info.groupby('Locality')
summaries = {}

for group in ['Toogreek', 'Nemegt', 'Altan Uul', 'Tsagan Khushuu', 'Bayan Dzak']:

    # frame for locality
    df = ppm_locs_group.get_group(group).iloc[:, :-2]

    # compositional centers
    centers = pd.Series( coda.clr_inv( np.mean( coda.clr( coda.closure( df.replace(0, 0.00001) ) ), axis=0 ) ), index=df.columns )
    centers_norm = ( 360_000 / centers['Ca'] ) * centers # normalize to Ca = 360_000 ppm

    # summary
    descr = df.describe()
    descr.loc['center', :] = centers_norm
    descr = descr.T.drop(columns='count', index='Ca').rename(columns={'50%' : 'median', '25%' : 'q_25', '75%' : 'q_75'})

    summaries[group] = descr

summaries_locs = pd.concat(summaries)

# %%
ppm_bones_group = ppm_info.groupby('Bone')
summaries = {}

for group in ['rib', 'metatarsal', 'tibia', 'femur', 'humerus', 'radius']:

    # frame for locality
    df = ppm_bones_group.get_group(group).iloc[:, :-2]

    # compositional centers
    centers = pd.Series( coda.clr_inv( np.mean( coda.clr( coda.closure( df.replace(0, 0.00001) ) ), axis=0 ) ), index=df.columns )
    centers_norm = ( 360_000 / centers['Ca'] ) * centers # normalize to Ca = 360_000 ppm

    # summary
    descr = df.describe()
    descr.loc['center', :] = centers_norm
    descr = descr.T.drop(columns='count', index='Ca').rename(columns={'50%' : 'median', '25%' : 'q_25', '75%' : 'q_75'})

    summaries[group] = descr

summaries_bones = pd.concat(summaries)

# %%
with pd.ExcelWriter('Data/Data description.xlsx') as writer:
    summaries_locs.to_excel(writer, sheet_name='Localities', merge_cells=False)
    summaries_bones.to_excel(writer, sheet_name='Bones', merge_cells=False)

# %%
ppmData = ppm.merge(spot_info, left_index=True, right_index=True)

# %% [markdown]
# ## LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
lda = LDA(n_components=3)

# %%
lda_train = lda.fit_transform(clr_data, localities)

# %%
data_lda = pd.DataFrame(
    data=lda_train,
    index=clr_data.index,
    columns=['LDA' + str(i) for i in range(1, 4)]
)

# %%
pd.DataFrame(
    data=lda.scalings_,
    index=clr_data.columns,
    columns=[f'LDA{i+1}' for i in range(4)]
)
# Out:
#         LDA1      LDA2      LDA3      LDA4
# Ca  1.828346  2.255868  2.285789  3.174010
# V  -0.115742 -0.762775  0.547699  0.421680
# Mn  1.143745  0.178517  0.665488 -0.259377
# Fe  0.431605  0.327294 -0.462117 -0.018141
# Cu -0.535863  0.008408  0.391390  0.274237
# Zn  0.160286  0.607267 -0.919107  0.138704
# Ga -0.676885  0.027117 -0.287299 -0.023946
# Rb  0.014931  0.038187 -0.021722 -0.040857
# Sr -2.378208 -1.860260 -0.728754 -3.228042
# Y  -0.572577  0.627134 -1.841578 -3.933352
# Ba -0.651792  0.069625 -0.439606 -0.300423
# La  0.202514  0.206581  0.415938 -0.027333
# Ce -0.005438 -0.052830 -0.004389  0.111123
# Pr  0.015429  0.008072 -0.006596 -0.039843
# Nd -0.000100 -0.007262 -0.002704  0.003264
# Sm  0.005443  0.003974  0.010670 -0.024697
# Eu  0.017618  0.011310 -0.006346 -0.010555
# Gd -0.007652 -0.019840  0.014489  0.003830
# Tb  0.017896  0.012556 -0.011168 -0.013297
# Dy -0.009664 -0.070234 -0.162282 -0.021024
# Ho  0.045758 -0.345177  0.435321  0.628926
# Er  0.320734  0.185844  0.055223  2.168148
# Tm  0.010366  0.023976  0.004480 -0.039070
# Yb  0.092942  2.914042  0.441180  0.249805
# Lu  0.028711 -4.104381  0.940394  1.404047
# Hf -0.037368 -0.052439  0.002236  0.033279
# Th -0.041324  0.069232  0.024592  0.008713
# U   0.870117 -0.245313 -1.325038 -0.514945

# %%
lda.explained_variance_ratio_
# Out:
# array([0.61984935, 0.17461535, 0.1404038 ])

# %%
data_lda = data_lda.merge(spot_info, left_index=True, right_index=True)

# %%
lda_scalings = pd.DataFrame(data=lda.scalings_,
                            index=clr_data.columns,
                            columns=[f'LDA{i+1}' for i in range(lda.scalings_.shape[1])])

# %%
lda_scalings.to_csv('LDA scalings.csv', sep=';')

# %%
trab_bones = data_lda[data_lda.Bone.isin(['rib', 'metatarsal', 'frill', 'vertebra', 'tooth'])]
long_bones = data_lda[~data_lda.Bone.isin(['rib', 'metatarsal', 'frill', 'vertebra', 'tooth'])]

# %%
data = long_bones.loc[:, 'LDA1':'LDA3']

# %%
lda.explained_variance_ratio_
# Out:
# array([0.61984935, 0.17461535, 0.1404038 ])

# %%
sns.color_palette('colorblind')
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.47058823529411764, 0.7372549019607844),
#  (0.792156862745098, 0.5686274509803921, 0.3803921568627451),
#  (0.984313725490196, 0.6862745098039216, 0.8941176470588236),
#  (0.5803921568627451, 0.5803921568627451, 0.5803921568627451),
#  (0.9254901960784314, 0.8823529411764706, 0.2),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784)]

# %%
sns.set_theme(context='notebook', palette='dark', style='ticks')

order_locs_1 = ['Bayan Dzak', 'Altan Uul', 'Nemegt', 'Tsagan Khushuu']
order_locs_2 = ['Toogreek', 'Altan Uul', 'Nemegt', 'Tsagan Khushuu']

dark_palette1 = np.array(sns.color_palette('colorblind'))[0:4].tolist()
dark_palette2 = np.array(sns.color_palette('colorblind'))[[4, 1, 2, 3]].tolist()

tick_labels = {
    'LDA1' : 'LD1 (59.58%)', 
    'LDA2' : 'LD2 (18.91%)', 
    'LDA3' : 'LD3 (13.90%)'
}

fig, ax = plt.subplots(2, 2, figsize=(10, 10))

ax00 = sns.scatterplot(long_bones, x='LDA1', y='LDA2', hue='Locality', s=15, ax=ax[0, 0], hue_order=order_locs_1, palette=dark_palette1)
ellipses_95_confidence('LDA1', 'LDA2', long_bones, 'Locality', dark_palette1, group_order=order_locs_1, ax=ax00)
ax00.set_xlabel(tick_labels['LDA1'])
ax00.set_ylabel(tick_labels['LDA2'])
ax00.legend().set_visible(False)

ax01 = sns.scatterplot(long_bones, x='LDA3', y='LDA2', hue='Locality', s=15, ax=ax[0, 1], hue_order=order_locs_1, legend=False, palette=dark_palette1)
ellipses_95_confidence('LDA3', 'LDA2', long_bones, 'Locality', dark_palette1, group_order=order_locs_1, ax=ax[0,1])
ax01.set_xlabel(tick_labels['LDA3'])
ax01.set_ylabel(tick_labels['LDA2'])

ax10 = sns.scatterplot(trab_bones, x='LDA1', y='LDA2', hue='Locality', s=15, ax=ax[1, 0], hue_order=order_locs_2, palette=dark_palette2)
ellipses_95_confidence('LDA1', 'LDA2', trab_bones, 'Locality', dark_palette2, group_order=order_locs_2, ax=ax[1,0])
ax10.set_xlabel(tick_labels['LDA1'])
ax10.set_ylabel(tick_labels['LDA2'])
ax10.legend().set_visible(False)

ax11 = sns.scatterplot(trab_bones, x='LDA3', y='LDA2', hue='Locality', s=15, ax=ax[1, 1], hue_order=order_locs_2, legend=False, palette=dark_palette2)
ellipses_95_confidence('LDA3', 'LDA2', trab_bones, 'Locality', dark_palette2, group_order=order_locs_2, ax=ax[1,1])
ax11.set_xlabel(tick_labels['LDA3'])
ax11.set_ylabel(tick_labels['LDA2'])

handAB, labAB = ax00.get_legend_handles_labels()
handCD, labCD = ax10.get_legend_handles_labels()

handles = [handAB[0]] + handCD
labels = [labAB[0]] + labCD

fig.legend(handles, labels, fontsize='medium', title_fontsize='x-large', loc='lower center', markerscale=1.5, ncols=5, bbox_to_anchor=(0.515, 0.0))

for num, axs in zip(["A", "B", "C", "D"], ax.flat):
    axs.text(0.03, 0.93, str(num), transform=axs.transAxes, bbox=dict(facecolor='white'), fontsize='x-large', fontweight='bold')

fig.savefig('Plots/LDA separation.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ---

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(class_weight='balanced')

# %%
logreg.fit(lb1_train, locs_lb1_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
locs_pred = logreg.predict(lb1_test)

# %%
acc_meas(locs_lb1_test, locs_pred)
# Out:
# accuracy score:    0.5
# f1 weighted score: 0.5002953464539556
# f1 micro score:    0.5

# %%
prediction_accuracy_frame(locs_lb1_test, locs_pred)
# Out:
#                      Locality PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak     Bayan Dzak            1.000000
#          L2        Bayan Dzak     Bayan Dzak            1.000000
#          L3        Bayan Dzak     Bayan Dzak            1.000000
# TS012    L1         Altan Uul      Altan Uul            1.000000
# TS020    L1            Nemegt         Nemegt            0.976744
# TS021    L1         Altan Uul         Nemegt            0.171429
# TS022    L1         Altan Uul         Nemegt            0.000000
#          L2         Altan Uul         Nemegt            0.058824
# TS029    L1            Nemegt      Altan Uul            0.150943
# TS030    L1    Tsagan Khushuu      Altan Uul            0.461538
#          L2    Tsagan Khushuu      Altan Uul            0.000000

# %% [markdown]
# ### Logistic Regression - LB1 - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
lr_params = {
    'C' : [0.01, 0.1, 1., 10], #np.logspace(-2, 2, 7),
    'multi_class' : ['ovr', 'multinomial'],
    'solver' : ['liblinear', 'saga', 'lbfgs', 'newton-cg', 'sag', 'newton-cholesky']
}

# %%
logreg_grid = GridSearchCV(LogisticRegression(random_state=13, class_weight='balanced'), param_grid=lr_params, cv=3, n_jobs=-1)

# %%
logreg_grid.fit(lb1_train, locs_lb1_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=LogisticRegression(class_weight='balanced',
#                                           random_state=13),
#              n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1.0, 10],
#                          'multi_class': ['ovr', 'multinomial'],
#                          'solver': ['liblinear', 'saga', 'lbfgs', 'newton-cg',
#                                     'sag', 'newton-cholesky']})

# %%
sorted_grid_logreg = grid_results_view(logreg_grid)

# %%
sorted_grid_logreg
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 41       0.047559      0.003258         0.003508    4.083525e-04    10.00
# 39       0.097737      0.021413         0.002666    4.704162e-04    10.00
# 36       0.015670      0.002868         0.003001    5.619580e-07    10.00
# 29       0.045230      0.006433         0.004668    1.700142e-03     1.00
# 27       0.083440      0.018211         0.002667    9.420664e-04     1.00
# 38       0.137475      0.026208         0.002667    4.722150e-04    10.00
# 24       0.018004      0.004900         0.002667    4.705275e-04     1.00
# 26       0.091444      0.011815         0.003001    2.081521e-06     1.00
# 44       0.098011      0.014726         0.003669    9.426848e-04    10.00
# 12       0.018514      0.004278         0.003665    9.444912e-04     0.10
# 33       0.095578      0.055912         0.002667    4.709208e-04     1.00
# 45       0.104447      0.018800         0.002333    4.721573e-04    10.00
# 14       0.095655      0.002869         0.004727    1.704168e-03     0.10
# 32       0.059012      0.010681         0.003000    8.151722e-04     1.00
# 15       0.075911      0.004085         0.003347    2.453509e-04     0.10
# 17       0.040648      0.006557         0.002481    4.567835e-04     0.10
# 20       0.046601      0.001886         0.003667    9.424597e-04     0.10
# 21       0.084751      0.010126         0.003001    8.173137e-04     0.10
# 40       0.119442      0.011361         0.003174    1.035368e-03    10.00
# 28       0.129784      0.022431         0.003334    4.714278e-04     1.00
# 16       0.097845      0.007588         0.003508    4.078617e-04     0.10
# 34       0.051185      0.009197         0.003510    1.071640e-03     1.00
# 46       0.043008      0.003559         0.003000    5.150430e-07    10.00
# 22       0.043530      0.004968         0.002668    4.705837e-04     0.10
# 0        0.016525      0.000704         0.020856    5.918133e-03     0.01
# 37       0.137635      0.016170         0.002668    4.726070e-04    10.00
# 25       0.098446      0.010659         0.010668    8.015488e-03     1.00
# 13       0.105503      0.002714         0.004839    1.014554e-03     0.10
# 8        0.060360      0.020860         0.003335    4.712586e-04     0.01
# 4        0.120097      0.022777         0.015035    1.670491e-03     0.01
# 10       0.045011      0.002449         0.004512    1.774569e-03     0.01
# 19       0.048231      0.003900         0.003668    4.715394e-04     0.10
# 31       0.057346      0.010502         0.003667    9.426286e-04     1.00
# 5        0.042689      0.012387         0.005001    2.160936e-03     0.01
# 3        0.075057      0.001881         0.014002    8.156597e-04     0.01
# 2        0.121617      0.006169         0.013509    6.957602e-04     0.01
# 43       0.101656      0.031593         0.003508    4.091781e-04    10.00
# 9        0.070682      0.002357         0.003002    7.370010e-07     0.01
# 7        0.065230      0.007336         0.004998    2.830808e-03     0.01
# 1        0.148995      0.024518         0.017003    4.242952e-03     0.01
#
#    param_multi_class     param_solver  \
# 41               ovr  newton-cholesky
# 39               ovr        newton-cg
# 36               ovr        liblinear
# 29               ovr  newton-cholesky
# 27               ovr        newton-cg
# 38               ovr            lbfgs
# 24               ovr        liblinear
# 26               ovr            lbfgs
# 44       multinomial            lbfgs
# 12               ovr        liblinear
# 33       multinomial        newton-cg
# 45       multinomial        newton-cg
# 14               ovr            lbfgs
# 32       multinomial            lbfgs
# 15               ovr        newton-cg
# 17               ovr  newton-cholesky
# 20       multinomial            lbfgs
# 21       multinomial        newton-cg
# 40               ovr              sag
# 28               ovr              sag
# 16               ovr              sag
# 34       multinomial              sag
# 46       multinomial              sag
# 22       multinomial              sag
# 0                ovr        liblinear
# 37               ovr             saga
# 25               ovr             saga
# 13               ovr             saga
# 8        multinomial            lbfgs
# 4                ovr              sag
# 10       multinomial              sag
# 19       multinomial             saga
# 31       multinomial             saga
# 5                ovr  newton-cholesky
# 3                ovr        newton-cg
# 2                ovr            lbfgs
# 43       multinomial             saga
# 9        multinomial        newton-cg
# 7        multinomial             saga
# 1                ovr             saga
#
#                                                params  split0_test_score  \
# 41  {'C': 10, 'multi_class': 'ovr', 'solver': 'new...           0.728205
# 39  {'C': 10, 'multi_class': 'ovr', 'solver': 'new...           0.728205
# 36  {'C': 10, 'multi_class': 'ovr', 'solver': 'lib...           0.728205
# 29  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'ne...           0.728205
# 27  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'ne...           0.728205
# 38  {'C': 10, 'multi_class': 'ovr', 'solver': 'lbf...           0.728205
# 24  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'li...           0.728205
# 26  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'lb...           0.728205
# 44  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.728205
# 12  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'li...           0.723077
# 33  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.728205
# 45  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.728205
# 14  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'lb...           0.717949
# 32  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.723077
# 15  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'ne...           0.717949
# 17  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'ne...           0.717949
# 20  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.723077
# 21  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.707692
# 40   {'C': 10, 'multi_class': 'ovr', 'solver': 'sag'}           0.702564
# 28  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'sag'}           0.702564
# 16  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'sag'}           0.702564
# 34  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.702564
# 46  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.702564
# 22  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.697436
# 0   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'l...           0.682051
# 37  {'C': 10, 'multi_class': 'ovr', 'solver': 'saga'}           0.671795
# 25  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'sa...           0.671795
# 13  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'sa...           0.671795
# 8   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.661538
# 4   {'C': 0.01, 'multi_class': 'ovr', 'solver': 's...           0.666667
# 10  {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.651282
# 19  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.666667
# 31  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.666667
# 5   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'n...           0.666667
# 3   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'n...           0.666667
# 2   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'l...           0.666667
# 43  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.666667
# 9   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.651282
# 7   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.641026
# 1   {'C': 0.01, 'multi_class': 'ovr', 'solver': 's...           0.661538
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 41           0.953608           0.984536         0.888783        0.114246
# 39           0.953608           0.984536         0.888783        0.114246
# 36           0.943299           0.984536         0.885347        0.112384
# 29           0.927835           0.963918         0.873319        0.103663
# 27           0.927835           0.963918         0.873319        0.103663
# 38           0.902062           0.984536         0.871601        0.106840
# 24           0.917526           0.953608         0.866446        0.098855
# 26           0.896907           0.974227         0.866446        0.102722
# 44           0.871134           0.948454         0.849264        0.091236
# 12           0.896907           0.912371         0.844118        0.085822
# 33           0.886598           0.912371         0.842391        0.081425
# 45           0.845361           0.948454         0.840673        0.089977
# 14           0.891753           0.902062         0.837254        0.084467
# 32           0.845361           0.943299         0.837246        0.090088
# 15           0.891753           0.886598         0.832100        0.080744
# 17           0.891753           0.886598         0.832100        0.080744
# 20           0.865979           0.902062         0.830373        0.077286
# 21           0.865979           0.902062         0.825245        0.084417
# 40           0.855670           0.896907         0.818380        0.083607
# 28           0.855670           0.896907         0.818380        0.083607
# 16           0.845361           0.891753         0.813226        0.080509
# 34           0.798969           0.902062         0.801198        0.081460
# 46           0.798969           0.902062         0.801198        0.081460
# 22           0.798969           0.896907         0.797771        0.081438
# 0            0.788660           0.896907         0.789206        0.087715
# 37           0.804124           0.881443         0.785787        0.086565
# 25           0.804124           0.881443         0.785787        0.086565
# 13           0.798969           0.881443         0.784069        0.086235
# 8            0.788660           0.881443         0.777214        0.090140
# 4            0.783505           0.876289         0.775487        0.085765
# 10           0.788660           0.881443         0.773795        0.094549
# 19           0.773196           0.881443         0.773769        0.087683
# 31           0.773196           0.881443         0.773769        0.087683
# 5            0.793814           0.860825         0.773769        0.080522
# 3            0.793814           0.860825         0.773769        0.080522
# 2            0.793814           0.860825         0.773769        0.080522
# 43           0.773196           0.881443         0.773769        0.087683
# 9            0.788660           0.876289         0.772077        0.092604
# 7            0.773196           0.881443         0.765222        0.098312
# 1            0.752577           0.876289         0.763468        0.088009
#
#     rank_test_score
# 41                1
# 39                1
# 36                3
# 29                4
# 27                4
# 38                6
# 24                7
# 26                7
# 44                9
# 12               10
# 33               11
# 45               12
# 14               13
# 32               14
# 15               15
# 17               15
# 20               17
# 21               18
# 40               19
# 28               19
# 16               21
# 34               22
# 46               22
# 22               24
# 0                25
# 37               26
# 25               26
# 13               28
# 8                29
# 4                30
# 10               31
# 19               32
# 31               32
# 5                32
# 3                32
# 2                32
# 43               32
# 9                38
# 7                39
# 1                40

# %%
logreg_lb1_bparams = sorted_grid_logreg.iloc[0]['params']

# %% [markdown]
# ### Logistic Regression - LB1 - Best Params

# %% [markdown]
# Fitted model

# %%
logreg_lb1_best = LogisticRegression(**logreg_lb1_bparams, random_state=13, class_weight='balanced') #, class_weight='balanced')

# %%
logreg_lb1_best.fit(lb1_train, locs_lb1_train)
# Out:
# LogisticRegression(C=10, class_weight='balanced', multi_class='ovr',
#                    random_state=13, solver='newton-cholesky')

# %% [markdown]
# Prediction and accuracy measures

# %%
# locs_pred = logreg.predict(lb1_test)
locs_pred = logreg_lb1_best.predict(lb1_test)

# %%
logreg_acc = acc_meas(locs_lb1_test, locs_pred, return_vals=True)
# Out:
# accuracy score:    0.4557823129251701
# f1 weighted score: 0.45766530943432254
# f1 micro score:    0.4557823129251701

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
logreg_predframe = prediction_accuracy_frame(locs_lb1_test, locs_pred)
display(logreg_predframe)
# Out:
#                      Locality PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak     Bayan Dzak            1.000000
#          L2        Bayan Dzak     Bayan Dzak            1.000000
#          L3        Bayan Dzak     Bayan Dzak            1.000000
# TS012    L1         Altan Uul      Altan Uul            1.000000
# TS020    L1            Nemegt         Nemegt            0.976744
# TS021    L1         Altan Uul         Nemegt            0.085714
# TS022    L1         Altan Uul         Nemegt            0.000000
#          L2         Altan Uul         Nemegt            0.000000
# TS029    L1            Nemegt      Altan Uul            0.000000
# TS030    L1    Tsagan Khushuu      Altan Uul            0.442308
#          L2    Tsagan Khushuu      Altan Uul            0.000000

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['logreg']['lb1'] = {'conf_mat' : confusion_matrix(locs_lb1_test, locs_pred, normalize='true', labels=lb_label_order), 'labels' : lb_label_acronym}

# %% [markdown]
# ---

# %% [markdown]
# ### Logistic Regression - LB2 - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
lr_params = {
    'C' : [0.01, 0.1, 1., 10], #np.logspace(-2, 2, 7),
    'multi_class' : ['ovr', 'multinomial'],
    'solver' : ['liblinear', 'saga', 'lbfgs', 'newton-cg', 'sag', 'newton-cholesky']
}

# %%
logreg_grid = GridSearchCV(LogisticRegression(random_state=13, class_weight='balanced'), param_grid=lr_params, cv=3, n_jobs=-1)

# %%
logreg_grid.fit(lb2_train, locs_lb2_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=LogisticRegression(class_weight='balanced',
#                                           random_state=13),
#              n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1.0, 10],
#                          'multi_class': ['ovr', 'multinomial'],
#                          'solver': ['liblinear', 'saga', 'lbfgs', 'newton-cg',
#                                     'sag', 'newton-cholesky']})

# %%
sorted_grid_logreg = grid_results_view(logreg_grid)

# %%
sorted_grid_logreg
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 38       0.087539      0.003267         0.003001    1.189441e-06    10.00
# 39       0.096366      0.028187         0.003001    1.011524e-06    10.00
# 26       0.090718      0.006111         0.002668    4.719323e-04     1.00
# 41       0.041182      0.003074         0.003001    1.168008e-06    10.00
# 36       0.016690      0.004163         0.003335    4.722134e-04    10.00
# 29       0.038367      0.003686         0.002333    4.723262e-04     1.00
# 27       0.080732      0.008717         0.003001    8.167300e-04     1.00
# 24       0.012001      0.000816         0.002334    4.714302e-04     1.00
# 45       0.074369      0.013787         0.002001    5.947204e-07    10.00
# 33       0.097756      0.027389         0.003329    4.640653e-04     1.00
# 44       0.044182      0.002584         0.002333    4.720449e-04    10.00
# 12       0.010002      0.000817         0.003001    8.177033e-04     0.10
# 0        0.006000      0.000819         0.001672    4.703588e-04     0.01
# 32       0.047010      0.003559         0.003001    1.106929e-06     1.00
# 40       0.079537      0.004901         0.002667    9.418978e-04    10.00
# 28       0.079381      0.001706         0.003334    4.722135e-04     1.00
# 20       0.045708      0.003681         0.003335    4.712047e-04     0.10
# 16       0.079388      0.003875         0.003001    8.151721e-04     0.10
# 14       0.095391      0.024935         0.005336    2.057995e-03     0.10
# 37       0.085019      0.001634         0.003680    8.484508e-04    10.00
# 13       0.086723      0.000464         0.003000    8.155633e-04     0.10
# 25       0.087382      0.005754         0.003335    4.714828e-04     1.00
# 1        0.086686      0.004646         0.003333    4.718203e-04     0.01
# 4        0.074684      0.009180         0.003668    4.720447e-04     0.01
# 17       0.030357      0.003876         0.002668    4.718206e-04     0.10
# 15       0.076041      0.008831         0.003001    5.947204e-07     0.10
# 8        0.047011      0.007258         0.003335    4.719890e-04     0.01
# 34       0.039071      0.000816         0.003001    8.163401e-04     1.00
# 46       0.034340      0.002496         0.001667    4.726073e-04    10.00
# 21       0.071706      0.004105         0.003000    8.104673e-07     0.10
# 22       0.040017      0.002967         0.003000    1.857014e-06     0.10
# 19       0.050378      0.007140         0.003000    1.325077e-06     0.10
# 7        0.041009      0.000816         0.003000    6.257699e-07     0.01
# 43       0.050196      0.004497         0.002333    4.713704e-04    10.00
# 31       0.046031      0.003266         0.003333    4.714278e-04     1.00
# 10       0.041343      0.004499         0.003668    4.717654e-04     0.01
# 5        0.031341      0.004113         0.003002    8.157566e-04     0.01
# 3        0.060681      0.002868         0.003001    2.247832e-07     0.01
# 2        0.068009      0.004242         0.003667    9.425721e-04     0.01
# 9        0.059014      0.005716         0.003001    1.215701e-06     0.01
#
#    param_multi_class     param_solver  \
# 38               ovr            lbfgs
# 39               ovr        newton-cg
# 26               ovr            lbfgs
# 41               ovr  newton-cholesky
# 36               ovr        liblinear
# 29               ovr  newton-cholesky
# 27               ovr        newton-cg
# 24               ovr        liblinear
# 45       multinomial        newton-cg
# 33       multinomial        newton-cg
# 44       multinomial            lbfgs
# 12               ovr        liblinear
# 0                ovr        liblinear
# 32       multinomial            lbfgs
# 40               ovr              sag
# 28               ovr              sag
# 20       multinomial            lbfgs
# 16               ovr              sag
# 14               ovr            lbfgs
# 37               ovr             saga
# 13               ovr             saga
# 25               ovr             saga
# 1                ovr             saga
# 4                ovr              sag
# 17               ovr  newton-cholesky
# 15               ovr        newton-cg
# 8        multinomial            lbfgs
# 34       multinomial              sag
# 46       multinomial              sag
# 21       multinomial        newton-cg
# 22       multinomial              sag
# 19       multinomial             saga
# 7        multinomial             saga
# 43       multinomial             saga
# 31       multinomial             saga
# 10       multinomial              sag
# 5                ovr  newton-cholesky
# 3                ovr        newton-cg
# 2                ovr            lbfgs
# 9        multinomial        newton-cg
#
#                                                params  split0_test_score  \
# 38  {'C': 10, 'multi_class': 'ovr', 'solver': 'lbf...           0.682635
# 39  {'C': 10, 'multi_class': 'ovr', 'solver': 'new...           0.682635
# 26  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'lb...           0.682635
# 41  {'C': 10, 'multi_class': 'ovr', 'solver': 'new...           0.682635
# 36  {'C': 10, 'multi_class': 'ovr', 'solver': 'lib...           0.682635
# 29  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'ne...           0.682635
# 27  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'ne...           0.682635
# 24  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'li...           0.682635
# 45  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.682635
# 33  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.682635
# 44  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.682635
# 12  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'li...           0.670659
# 0   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'l...           0.634731
# 32  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.682635
# 40   {'C': 10, 'multi_class': 'ovr', 'solver': 'sag'}           0.652695
# 28  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'sag'}           0.652695
# 20  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.676647
# 16  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'sag'}           0.646707
# 14  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'lb...           0.658683
# 37  {'C': 10, 'multi_class': 'ovr', 'solver': 'saga'}           0.634731
# 13  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'sa...           0.628743
# 25  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'sa...           0.628743
# 1   {'C': 0.01, 'multi_class': 'ovr', 'solver': 's...           0.616766
# 4   {'C': 0.01, 'multi_class': 'ovr', 'solver': 's...           0.616766
# 17  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'ne...           0.652695
# 15  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'ne...           0.652695
# 8   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.604790
# 34  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.652695
# 46  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.652695
# 21  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.646707
# 22  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.646707
# 19  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.616766
# 7   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.598802
# 43  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.616766
# 31  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.616766
# 10  {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.598802
# 5   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'n...           0.598802
# 3   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'n...           0.598802
# 2   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'l...           0.598802
# 9   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.580838
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 38           0.922156           0.891566         0.832119        0.106436
# 39           0.940120           0.873494         0.832083        0.109120
# 26           0.928144           0.879518         0.830099        0.106146
# 41           0.940120           0.867470         0.830075        0.108393
# 36           0.916168           0.867470         0.822091        0.100594
# 29           0.928144           0.855422         0.822067        0.102966
# 27           0.928144           0.855422         0.822067        0.102966
# 24           0.916168           0.849398         0.816067        0.098209
# 45           0.940120           0.819277         0.814011        0.105184
# 33           0.934132           0.801205         0.805990        0.102729
# 44           0.916168           0.807229         0.802010        0.095411
# 12           0.928144           0.807229         0.802010        0.105183
# 0            0.922156           0.831325         0.796071        0.119960
# 32           0.922156           0.759036         0.787942        0.099897
# 40           0.916168           0.789157         0.786006        0.107585
# 28           0.916168           0.789157         0.786006        0.107585
# 20           0.940120           0.734940         0.783902        0.112997
# 16           0.916168           0.783133         0.782002        0.110010
# 14           0.916168           0.771084         0.781978        0.105400
# 37           0.910180           0.795181         0.780030        0.112961
# 13           0.910180           0.795181         0.778034        0.115534
# 25           0.910180           0.795181         0.778034        0.115534
# 1            0.910180           0.795181         0.774042        0.120714
# 4            0.916168           0.789157         0.774030        0.122697
# 17           0.916168           0.753012         0.773958        0.108577
# 15           0.916168           0.753012         0.773958        0.108577
# 8            0.934132           0.753012         0.763978        0.134676
# 34           0.916168           0.716867         0.761910        0.112179
# 46           0.916168           0.716867         0.761910        0.112179
# 21           0.934132           0.704819         0.761886        0.124085
# 22           0.916168           0.716867         0.759914        0.114140
# 19           0.916168           0.740964         0.757966        0.122820
# 7            0.916168           0.753012         0.755994        0.129581
# 43           0.916168           0.734940         0.755958        0.123130
# 31           0.916168           0.734940         0.755958        0.123130
# 10           0.916168           0.740964         0.751978        0.129798
# 5            0.904192           0.746988         0.749994        0.124693
# 3            0.904192           0.746988         0.749994        0.124693
# 2            0.904192           0.746988         0.749994        0.124693
# 9            0.934132           0.722892         0.745954        0.145150
#
#     rank_test_score
# 38                1
# 39                2
# 26                3
# 41                4
# 36                5
# 29                6
# 27                6
# 24                8
# 45                9
# 33               10
# 44               11
# 12               11
# 0                13
# 32               14
# 40               15
# 28               15
# 20               17
# 16               18
# 14               19
# 37               20
# 13               21
# 25               21
# 1                23
# 4                24
# 17               25
# 15               25
# 8                27
# 34               28
# 46               28
# 21               30
# 22               31
# 19               32
# 7                33
# 43               34
# 31               34
# 10               36
# 5                37
# 3                37
# 2                37
# 9                40

# %%
logreg_lb2_bparams = sorted_grid_logreg.iloc[0]['params']

# %% [markdown]
# ### Logistic Regression - LB2 - Best Params

# %% [markdown]
# Fitted model

# %%
logreg_lb2_best = LogisticRegression(**logreg_lb2_bparams, random_state=13, class_weight='balanced') #, class_weight='balanced')

# %%
logreg_lb2_best.fit(lb2_train, locs_lb2_train)
# Out:
# LogisticRegression(C=10, class_weight='balanced', multi_class='ovr',
#                    random_state=13)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_pred = logreg_lb2_best.predict(lb2_test)

# %%
logreg_acc = acc_meas(locs_lb2_test, locs_pred, return_vals=True)
# Out:
# accuracy score:    0.5095785440613027
# f1 weighted score: 0.5085765400955894
# f1 micro score:    0.5095785440613027

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
logreg_predframe = prediction_accuracy_frame(locs_lb2_test, locs_pred)
display(logreg_predframe)
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak      Bayan Dzak            1.000000
#          L2        Bayan Dzak      Bayan Dzak            1.000000
#          L3        Bayan Dzak      Bayan Dzak            1.000000
# TS012    L1         Altan Uul       Altan Uul            0.974359
# TS020    L1            Nemegt          Nemegt            0.976744
# TS021    L1         Altan Uul          Nemegt            0.142857
# TS029    L1            Nemegt  Tsagan Khushuu            0.018868
# TS030    L1    Tsagan Khushuu       Altan Uul            0.384615
#          L2    Tsagan Khushuu       Altan Uul            0.000000

# %%
lb2_results['Predict_logreg'] = lb2_results['Locality'] == locs_pred

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['logreg']['lb2'] = {'conf_mat' : confusion_matrix(locs_lb2_test, locs_pred, normalize='true', labels=lb_label_order), 'labels' : lb_label_acronym}

# %% [markdown]
# ---

# %% [markdown]
# ### Logistic Regression - TB - Hyperparameters

# %%
lr_params = {
    'C' : [0.01, 0.1, 1., 10], #np.logspace(-2, 2, 7),
    'multi_class' : ['ovr', 'multinomial'],
    'solver' : ['liblinear', 'saga', 'lbfgs', 'newton-cg', 'sag', 'newton-cholesky']
}

# %%
logreg_grid = GridSearchCV(LogisticRegression(random_state=13, class_weight='balanced'), param_grid=lr_params, cv=3, n_jobs=-1)

# %%
logreg_grid.fit(tb_train, locs_tb_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=LogisticRegression(class_weight='balanced',
#                                           random_state=13),
#              n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1.0, 10],
#                          'multi_class': ['ovr', 'multinomial'],
#                          'solver': ['liblinear', 'saga', 'lbfgs', 'newton-cg',
#                                     'sag', 'newton-cholesky']})

# %%
sorted_grid_logreg = grid_results_view(logreg_grid)

# %%
sorted_grid_logreg
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 46       0.016914      0.001699         0.002001    1.140650e-06    10.00
# 1        0.037676      0.008058         0.005336    2.056616e-03     0.01
# 40       0.045010      0.000816         0.004334    4.714282e-04    10.00
# 4        0.028670      0.000945         0.003083    1.162129e-04     0.01
# 37       0.044936      0.004322         0.002999    2.153113e-06    10.00
# 34       0.021671      0.001886         0.003003    9.199649e-07     1.00
# 28       0.047010      0.005718         0.003668    4.742380e-04     1.00
# 26       0.077328      0.000980         0.003001    8.172176e-04     1.00
# 12       0.011003      0.000816         0.002668    4.708086e-04     0.10
# 13       0.048821      0.001405         0.004189    1.995688e-03     0.10
# 25       0.059345      0.004192         0.002669    4.739555e-04     1.00
# 24       0.009001      0.000816         0.002668    4.715474e-04     1.00
# 16       0.051010      0.006482         0.003001    1.381091e-06     0.10
# 20       0.041342      0.002494         0.003001    8.156588e-04     0.10
# 43       0.022580      0.001153         0.003336    4.712918e-04    10.00
# 31       0.026338      0.001700         0.003000    1.784161e-06     1.00
# 22       0.024671      0.005250         0.003335    4.699663e-04     0.10
# 44       0.033584      0.002160         0.002334    4.726134e-04    10.00
# 39       0.065685      0.005313         0.002666    4.729517e-04    10.00
# 38       0.057271      0.003771         0.003667    4.705836e-04    10.00
# 36       0.007336      0.000471         0.003001    1.184119e-06    10.00
# 10       0.012336      0.000942         0.002334    4.721014e-04     0.01
# 19       0.025005      0.000816         0.003335    4.718267e-04     0.10
# 7        0.019337      0.001250         0.002667    9.439209e-04     0.01
# 17       0.025004      0.002946         0.003000    5.840039e-07     0.10
# 15       0.064905      0.007917         0.002668    4.713142e-04     0.10
# 14       0.079683      0.012368         0.002669    4.707527e-04     0.10
# 32       0.044344      0.006344         0.003668    9.428532e-04     1.00
# 41       0.033672      0.002360         0.003669    4.709782e-04    10.00
# 27       0.075301      0.008210         0.003335    1.247426e-03     1.00
# 0        0.004001      0.000816         0.001670    4.678300e-04     0.01
# 45       0.033587      0.002449         0.001333    4.692353e-04    10.00
# 29       0.029674      0.000472         0.002999    8.178029e-04     1.00
# 21       0.056680      0.009465         0.002668    4.720447e-04     0.10
# 33       0.048652      0.006099         0.003000    8.171227e-04     1.00
# 5        0.024674      0.004785         0.002666    4.733940e-04     0.01
# 3        0.041004      0.006163         0.002667    4.714270e-04     0.01
# 2        0.046344      0.006598         0.003334    4.729464e-04     0.01
# 9        0.032008      0.005356         0.003000    8.185789e-04     0.01
# 8        0.032674      0.000472         0.003342    4.825538e-04     0.01
#
#    param_multi_class     param_solver  \
# 46       multinomial              sag
# 1                ovr             saga
# 40               ovr              sag
# 4                ovr              sag
# 37               ovr             saga
# 34       multinomial              sag
# 28               ovr              sag
# 26               ovr            lbfgs
# 12               ovr        liblinear
# 13               ovr             saga
# 25               ovr             saga
# 24               ovr        liblinear
# 16               ovr              sag
# 20       multinomial            lbfgs
# 43       multinomial             saga
# 31       multinomial             saga
# 22       multinomial              sag
# 44       multinomial            lbfgs
# 39               ovr        newton-cg
# 38               ovr            lbfgs
# 36               ovr        liblinear
# 10       multinomial              sag
# 19       multinomial             saga
# 7        multinomial             saga
# 17               ovr  newton-cholesky
# 15               ovr        newton-cg
# 14               ovr            lbfgs
# 32       multinomial            lbfgs
# 41               ovr  newton-cholesky
# 27               ovr        newton-cg
# 0                ovr        liblinear
# 45       multinomial        newton-cg
# 29               ovr  newton-cholesky
# 21       multinomial        newton-cg
# 33       multinomial        newton-cg
# 5                ovr  newton-cholesky
# 3                ovr        newton-cg
# 2                ovr            lbfgs
# 9        multinomial        newton-cg
# 8        multinomial            lbfgs
#
#                                                params  split0_test_score  \
# 46  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.976471
# 1   {'C': 0.01, 'multi_class': 'ovr', 'solver': 's...           0.976471
# 40   {'C': 10, 'multi_class': 'ovr', 'solver': 'sag'}           0.976471
# 4   {'C': 0.01, 'multi_class': 'ovr', 'solver': 's...           0.976471
# 37  {'C': 10, 'multi_class': 'ovr', 'solver': 'saga'}           0.976471
# 34  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.976471
# 28  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'sag'}           0.976471
# 26  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'lb...           0.976471
# 12  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'li...           0.976471
# 13  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'sa...           0.976471
# 25  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'sa...           0.976471
# 24  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'li...           0.976471
# 16  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'sag'}           0.976471
# 20  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.976471
# 43  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.976471
# 31  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.976471
# 22  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.976471
# 44  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.988235
# 39  {'C': 10, 'multi_class': 'ovr', 'solver': 'new...           0.988235
# 38  {'C': 10, 'multi_class': 'ovr', 'solver': 'lbf...           0.988235
# 36  {'C': 10, 'multi_class': 'ovr', 'solver': 'lib...           0.988235
# 10  {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.964706
# 19  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.964706
# 7   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.964706
# 17  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'ne...           0.976471
# 15  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'ne...           0.976471
# 14  {'C': 0.1, 'multi_class': 'ovr', 'solver': 'lb...           0.976471
# 32  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.976471
# 41  {'C': 10, 'multi_class': 'ovr', 'solver': 'new...           0.988235
# 27  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'ne...           0.976471
# 0   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'l...           0.952941
# 45  {'C': 10, 'multi_class': 'multinomial', 'solve...           0.988235
# 29  {'C': 1.0, 'multi_class': 'ovr', 'solver': 'ne...           0.976471
# 21  {'C': 0.1, 'multi_class': 'multinomial', 'solv...           0.976471
# 33  {'C': 1.0, 'multi_class': 'multinomial', 'solv...           0.976471
# 5   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'n...           0.976471
# 3   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'n...           0.976471
# 2   {'C': 0.01, 'multi_class': 'ovr', 'solver': 'l...           0.976471
# 9   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.964706
# 8   {'C': 0.01, 'multi_class': 'multinomial', 'sol...           0.964706
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 46           0.988095           0.892857         0.952474        0.042422
# 1            1.000000           0.880952         0.952474        0.051478
# 40           1.000000           0.880952         0.952474        0.051478
# 4            1.000000           0.880952         0.952474        0.051478
# 37           1.000000           0.880952         0.952474        0.051478
# 34           0.988095           0.892857         0.952474        0.042422
# 28           1.000000           0.880952         0.952474        0.051478
# 26           0.988095           0.892857         0.952474        0.042422
# 12           1.000000           0.880952         0.952474        0.051478
# 13           1.000000           0.880952         0.952474        0.051478
# 25           1.000000           0.880952         0.952474        0.051478
# 24           0.988095           0.892857         0.952474        0.042422
# 16           1.000000           0.880952         0.952474        0.051478
# 20           0.988095           0.892857         0.952474        0.042422
# 43           1.000000           0.869048         0.948506        0.057001
# 31           1.000000           0.869048         0.948506        0.057001
# 22           1.000000           0.869048         0.948506        0.057001
# 44           0.988095           0.869048         0.948459        0.056153
# 39           0.988095           0.869048         0.948459        0.056153
# 38           0.988095           0.869048         0.948459        0.056153
# 36           0.988095           0.869048         0.948459        0.056153
# 10           1.000000           0.869048         0.944585        0.055322
# 19           1.000000           0.869048         0.944585        0.055322
# 7            1.000000           0.869048         0.944585        0.055322
# 17           1.000000           0.857143         0.944538        0.062540
# 15           1.000000           0.857143         0.944538        0.062540
# 14           1.000000           0.857143         0.944538        0.062540
# 32           0.988095           0.869048         0.944538        0.053590
# 41           0.988095           0.857143         0.944491        0.061765
# 27           0.988095           0.857143         0.940570        0.059182
# 0            1.000000           0.857143         0.936695        0.059442
# 45           0.988095           0.833333         0.936555        0.072988
# 29           0.988095           0.833333         0.932633        0.070376
# 21           0.988095           0.833333         0.932633        0.070376
# 33           0.988095           0.833333         0.932633        0.070376
# 5            1.000000           0.821429         0.932633        0.079218
# 3            1.000000           0.821429         0.932633        0.079218
# 2            1.000000           0.821429         0.932633        0.079218
# 9            1.000000           0.821429         0.928711        0.077217
# 8            0.988095           0.809524         0.920775        0.079244
#
#     rank_test_score
# 46                1
# 1                 1
# 40                1
# 4                 1
# 37                1
# 34                1
# 28                1
# 26                1
# 12                1
# 13                1
# 25                1
# 24                1
# 16                1
# 20                1
# 43               15
# 31               15
# 22               15
# 44               18
# 39               18
# 38               18
# 36               18
# 10               22
# 19               22
# 7                22
# 17               25
# 15               25
# 14               25
# 32               25
# 41               29
# 27               30
# 0                31
# 45               32
# 29               33
# 21               33
# 33               33
# 5                36
# 3                36
# 2                36
# 9                39
# 8                40

# %%
logreg_tb_bparams = sorted_grid_logreg.iloc[0]['params']

# %% [markdown]
# ### Logistic Regression - TB - Best Params

# %% [markdown]
# Fitted model

# %%
logreg_tb = LogisticRegression(class_weight='balanced', random_state=13, **logreg_tb_bparams)
logreg_tb.fit(tb_train, locs_tb_train)
# Out:
# LogisticRegression(C=10, class_weight='balanced', multi_class='multinomial',
#                    random_state=13, solver='sag')

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_tb_pred = logreg_tb.predict(tb_test)

# %%
logreg_acc = acc_meas(locs_tb_test, locs_tb_pred, return_vals=True)
# Out:
# accuracy score:    0.5123456790123457
# f1 weighted score: 0.4802719262691657
# f1 micro score:    0.5123456790123457

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
logreg_tb_predframe = prediction_accuracy_frame(locs_tb_test, locs_tb_pred)
display(logreg_tb_predframe)
# Out:
#                      Locality       PredictionMode  PredictionAccuracy
# SampleID Line
# PR001    L1          Toogreek             Toogreek              1.0000
# SF003    L1         Altan Uul  [Altan Uul, Nemegt]              0.5000
#          L2         Altan Uul            Altan Uul              1.0000
#          L3         Altan Uul            Altan Uul              1.0000
#          L4         Altan Uul            Altan Uul              0.6000
# TF028    L1            Nemegt               Nemegt              1.0000
#          L2            Nemegt               Nemegt              0.9375
#          L3            Nemegt            Altan Uul              0.0000
#          L4            Nemegt            Altan Uul              0.0000
# TS027    L1    Tsagan Khushuu            Altan Uul              0.0000
#          L2    Tsagan Khushuu               Nemegt              0.0000
#          L3    Tsagan Khushuu            Altan Uul              0.0000

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['logreg']['tb'] = {'conf_mat' : confusion_matrix(locs_tb_test, locs_tb_pred, normalize='true', labels=tb_label_order), 'labels' : tb_label_acronym}

# %% [markdown]
# ---

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(criterion="entropy", class_weight='balanced')

# %%
forest.fit(lb1_train, locs_lb1_train)
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='entropy')

# %%
locs_pred = forest.predict(lb1_test)

# %%
acc_meas(locs_lb1_test, locs_pred)
# Out:
# accuracy score:    0.6870748299319728
# f1 weighted score: 0.6790726461103265
# f1 micro score:    0.6870748299319728

# %%
prediction_accuracy_frame(locs_lb1_test, locs_pred)
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak      Bayan Dzak            0.700000
#          L2        Bayan Dzak      Bayan Dzak            0.888889
#          L3        Bayan Dzak      Bayan Dzak            0.750000
# TS012    L1         Altan Uul       Altan Uul            1.000000
# TS020    L1            Nemegt          Nemegt            0.976744
# TS021    L1         Altan Uul          Nemegt            0.085714
# TS022    L1         Altan Uul          Nemegt            0.187500
#          L2         Altan Uul          Nemegt            0.176471
# TS029    L1            Nemegt          Nemegt            0.754717
# TS030    L1    Tsagan Khushuu  Tsagan Khushuu            0.750000
#          L2    Tsagan Khushuu  Tsagan Khushuu            1.000000

# %% [markdown]
# ### Random Forest - LB1 - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
forest_params = {
    'criterion' : ['log_loss'],
    'n_estimators' : [100, 150],
    'max_depth' : [5, 6],
    'min_samples_leaf' : [1, 2],
    'max_features' : [None, 'log2', 'sqrt']
}

# %%
forest_const_params = {
    'random_state' : 13,
    'warm_start' : True,
    'class_weight' : 'balanced'
}

# %%
forest_grid = GridSearchCV(estimator=RandomForestClassifier(**forest_const_params), param_grid=forest_params, cv=3, n_jobs=-1)

# %%
forest_grid.fit(lb1_train, locs_lb1_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=13,
#                                               warm_start=True),
#              n_jobs=-1,
#              param_grid={'criterion': ['log_loss'], 'max_depth': [5, 6],
#                          'max_features': [None, 'log2', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'n_estimators': [100, 150]})

# %%
sorted_grid_forest = grid_results_view(forest_grid)

# %%
sorted_grid_forest
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6        0.319616      0.060893         0.009518        0.000007
# 18       0.318453      0.018084         0.009678        0.000479
# 4        0.305147      0.007774         0.009336        0.001248
# 21       0.489360      0.013933         0.007836        0.000625
# 19       0.478823      0.028061         0.011679        0.002327
# 11       0.506851      0.021722         0.013505        0.001078
# 20       0.350387      0.021183         0.010011        0.000409
# 7        0.504296      0.036518         0.014012        0.001876
# 17       0.480880      0.037438         0.012508        0.000407
# 8        0.353501      0.035553         0.010677        0.000626
# 23       0.368527      0.008049         0.007202        0.000228
# 16       0.317105      0.015650         0.009850        0.000472
# 5        0.455670      0.022580         0.012510        0.000817
# 9        0.543408      0.025943         0.013171        0.000851
# 22       0.345757      0.022096         0.010514        0.000818
# 10       0.364089      0.025376         0.010851        0.001886
# 12       0.833428      0.164924         0.009174        0.000243
# 1        1.202329      0.234799         0.018843        0.005861
# 0        0.774880      0.131811         0.010170        0.001033
# 13       1.235004      0.244426         0.011509        0.002123
# 14       0.860066      0.168588         0.010174        0.000242
# 15       1.223956      0.230401         0.010839        0.002951
# 3        1.172800      0.196707         0.014688        0.001243
# 2        0.777722      0.139187         0.010840        0.000628
#
#    param_criterion  param_max_depth param_max_features  \
# 6         log_loss                5               log2
# 18        log_loss                6               log2
# 4         log_loss                5               log2
# 21        log_loss                6               sqrt
# 19        log_loss                6               log2
# 11        log_loss                5               sqrt
# 20        log_loss                6               sqrt
# 7         log_loss                5               log2
# 17        log_loss                6               log2
# 8         log_loss                5               sqrt
# 23        log_loss                6               sqrt
# 16        log_loss                6               log2
# 5         log_loss                5               log2
# 9         log_loss                5               sqrt
# 22        log_loss                6               sqrt
# 10        log_loss                5               sqrt
# 12        log_loss                6               None
# 1         log_loss                5               None
# 0         log_loss                5               None
# 13        log_loss                6               None
# 14        log_loss                6               None
# 15        log_loss                6               None
# 3         log_loss                5               None
# 2         log_loss                5               None
#
#     param_min_samples_leaf  param_n_estimators  \
# 6                        2                 100
# 18                       2                 100
# 4                        1                 100
# 21                       1                 150
# 19                       2                 150
# 11                       2                 150
# 20                       1                 100
# 7                        2                 150
# 17                       1                 150
# 8                        1                 100
# 23                       2                 150
# 16                       1                 100
# 5                        1                 150
# 9                        1                 150
# 22                       2                 100
# 10                       2                 100
# 12                       1                 100
# 1                        1                 150
# 0                        1                 100
# 13                       1                 150
# 14                       2                 100
# 15                       2                 150
# 3                        2                 150
# 2                        2                 100
#
#                                                params  split0_test_score  \
# 6   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.707692
# 18  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.707692
# 4   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.707692
# 21  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.723077
# 19  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.712821
# 11  {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.723077
# 20  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.723077
# 7   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.712821
# 17  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.712821
# 8   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.723077
# 23  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.723077
# 16  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.702564
# 5   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.707692
# 9   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.717949
# 22  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.723077
# 10  {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.723077
# 12  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.528205
# 1   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.528205
# 0   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.528205
# 13  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.528205
# 14  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.528205
# 15  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.528205
# 3   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.528205
# 2   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.528205
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 6            0.958763                1.0         0.888818        0.129177
# 18           0.953608                1.0         0.887100        0.128266
# 4            0.943299                1.0         0.883664        0.126565
# 21           0.922680                1.0         0.881919        0.116670
# 19           0.927835                1.0         0.880219        0.121980
# 11           0.912371                1.0         0.878483        0.115565
# 20           0.912371                1.0         0.878483        0.115565
# 7            0.917526                1.0         0.876782        0.120728
# 17           0.917526                1.0         0.876782        0.120728
# 8            0.907216                1.0         0.876764        0.115086
# 23           0.902062                1.0         0.875046        0.114656
# 16           0.917526                1.0         0.873363        0.125379
# 5            0.912371                1.0         0.873354        0.122482
# 9            0.902062                1.0         0.873337        0.116925
# 22           0.896907                1.0         0.873328        0.114276
# 10           0.891753                1.0         0.871610        0.113947
# 12           0.994845                1.0         0.841017        0.221201
# 1            0.994845                1.0         0.841017        0.221201
# 0            0.994845                1.0         0.841017        0.221201
# 13           0.989691                1.0         0.839299        0.220017
# 14           0.989691                1.0         0.839299        0.220017
# 15           0.989691                1.0         0.839299        0.220017
# 3            0.989691                1.0         0.839299        0.220017
# 2            0.989691                1.0         0.839299        0.220017
#
#     rank_test_score
# 6                 1
# 18                2
# 4                 3
# 21                4
# 19                5
# 11                6
# 20                6
# 7                 8
# 17                8
# 8                10
# 23               11
# 16               12
# 5                13
# 9                14
# 22               15
# 10               16
# 12               17
# 1                17
# 0                17
# 13               20
# 14               20
# 15               20
# 3                20
# 2                20

# %% [markdown]
# **Best parameters** for the algorithm

# %%
forest_lb1_bparams = sorted_grid_forest.iloc[0]['params']

# %% [markdown]
# ### Random Forest - LB1 - Best Params

# %% [markdown]
# Fitted model

# %%
forest_lb1_best = RandomForestClassifier(**forest_lb1_bparams, **forest_const_params)

# %%
forest_lb1_best.fit(lb1_train, locs_lb1_train)
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='log_loss',
#                        max_depth=5, max_features='log2', min_samples_leaf=2,
#                        random_state=13, warm_start=True)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_pred = forest_lb1_best.predict(lb1_test)

# %%
forest_acc = acc_meas(locs_lb1_test, locs_pred, return_vals=True)
# Out:
# accuracy score:    0.717687074829932
# f1 weighted score: 0.7061478443887484
# f1 micro score:    0.717687074829932

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
forest_predframe = prediction_accuracy_frame(locs_lb1_test, locs_pred)
display(forest_predframe)
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak      Bayan Dzak            0.800000
#          L2        Bayan Dzak      Bayan Dzak            1.000000
#          L3        Bayan Dzak      Bayan Dzak            0.875000
# TS012    L1         Altan Uul       Altan Uul            0.923077
# TS020    L1            Nemegt          Nemegt            1.000000
# TS021    L1         Altan Uul          Nemegt            0.171429
# TS022    L1         Altan Uul          Nemegt            0.187500
#          L2         Altan Uul          Nemegt            0.058824
# TS029    L1            Nemegt          Nemegt            0.660377
# TS030    L1    Tsagan Khushuu  Tsagan Khushuu            0.980769
#          L2    Tsagan Khushuu  Tsagan Khushuu            1.000000

# %%
forest_predframe.groupby('Locality')['PredictionAccuracy'].mean()
# Out:
# Locality
# Altan Uul         0.335207
# Bayan Dzak        0.891667
# Nemegt            0.830189
# Tsagan Khushuu    0.990385
# Name: PredictionAccuracy, dtype: float64

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['forest']['lb1'] = {'conf_mat' : confusion_matrix(locs_lb1_test, locs_pred, normalize='true', labels=lb_label_order), 'labels' : lb_label_acronym}

# %% [markdown]
# ---

# %% [markdown]
# ### Random Forest - LB2 - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
forest_params = {
    'criterion' : ['log_loss'],
    'n_estimators' : [100, 150],
    'max_depth' : [5, 6],
    'min_samples_leaf' : [1, 2],
    'max_features' : [None, 'log2', 'sqrt']
}

# %%
forest_const_params = {
    'random_state' : 13,
    'warm_start' : True,
    'class_weight' : 'balanced'
}

# %%
forest_grid = GridSearchCV(estimator=RandomForestClassifier(**forest_const_params), param_grid=forest_params, cv=3, n_jobs=-1)

# %%
forest_grid.fit(lb2_train, locs_lb2_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=13,
#                                               warm_start=True),
#              n_jobs=-1,
#              param_grid={'criterion': ['log_loss'], 'max_depth': [5, 6],
#                          'max_features': [None, 'log2', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'n_estimators': [100, 150]})

# %%
sorted_grid_forest = grid_results_view(forest_grid)

# %%
sorted_grid_forest
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 21       0.464525      0.016666         0.009507        0.001777
# 23       0.333283      0.004487         0.008009        0.000405
# 9        0.468537      0.039123         0.012846        0.001539
# 11       0.479409      0.022644         0.012169        0.000240
# 22       0.319668      0.002017         0.008152        0.000970
# 20       0.352252      0.022145         0.009852        0.000941
# 8        0.311399      0.011267         0.010174        0.000245
# 16       0.315797      0.030109         0.010514        0.001088
# 10       0.311415      0.012540         0.012357        0.002319
# 17       0.456196      0.046022         0.013527        0.001081
# 19       0.460415      0.034081         0.011357        0.002100
# 13       1.128696      0.196232         0.013849        0.000467
# 1        1.018934      0.159503         0.014187        0.000635
# 12       0.776229      0.115287         0.009184        0.000474
# 14       0.802930      0.166226         0.010507        0.001076
# 15       1.127322      0.168017         0.012510        0.003192
# 0        0.674469      0.110879         0.009344        0.000854
# 2        0.660630      0.116100         0.009175        0.000618
# 3        1.014395      0.161133         0.013348        0.000245
# 4        0.289205      0.010722         0.009507        0.001077
# 5        0.412630      0.009075         0.013181        0.001435
# 18       0.333089      0.032208         0.010171        0.000242
# 7        0.418051      0.023307         0.013173        0.000619
# 6        0.267738      0.015072         0.008677        0.000231
#
#    param_criterion  param_max_depth param_max_features  \
# 21        log_loss                6               sqrt
# 23        log_loss                6               sqrt
# 9         log_loss                5               sqrt
# 11        log_loss                5               sqrt
# 22        log_loss                6               sqrt
# 20        log_loss                6               sqrt
# 8         log_loss                5               sqrt
# 16        log_loss                6               log2
# 10        log_loss                5               sqrt
# 17        log_loss                6               log2
# 19        log_loss                6               log2
# 13        log_loss                6               None
# 1         log_loss                5               None
# 12        log_loss                6               None
# 14        log_loss                6               None
# 15        log_loss                6               None
# 0         log_loss                5               None
# 2         log_loss                5               None
# 3         log_loss                5               None
# 4         log_loss                5               log2
# 5         log_loss                5               log2
# 18        log_loss                6               log2
# 7         log_loss                5               log2
# 6         log_loss                5               log2
#
#     param_min_samples_leaf  param_n_estimators  \
# 21                       1                 150
# 23                       2                 150
# 9                        1                 150
# 11                       2                 150
# 22                       2                 100
# 20                       1                 100
# 8                        1                 100
# 16                       1                 100
# 10                       2                 100
# 17                       1                 150
# 19                       2                 150
# 13                       1                 150
# 1                        1                 150
# 12                       1                 100
# 14                       2                 100
# 15                       2                 150
# 0                        1                 100
# 2                        2                 100
# 3                        2                 150
# 4                        1                 100
# 5                        1                 150
# 18                       2                 100
# 7                        2                 150
# 6                        2                 100
#
#                                                params  split0_test_score  \
# 21  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.688623
# 23  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.682635
# 9   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.688623
# 11  {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.682635
# 22  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.676647
# 20  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.688623
# 8   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.682635
# 16  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.664671
# 10  {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.670659
# 17  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.664671
# 19  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.658683
# 13  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.473054
# 1   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.473054
# 12  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.473054
# 14  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.473054
# 15  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.473054
# 0   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.473054
# 2   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.473054
# 3   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.473054
# 4   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.634731
# 5   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.664671
# 18  {'criterion': 'log_loss', 'max_depth': 6, 'max...           0.616766
# 7   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.658683
# 6   {'criterion': 'log_loss', 'max_depth': 5, 'max...           0.604790
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 21           0.988024           0.903614         0.860087        0.126046
# 23           0.988024           0.897590         0.856083        0.128083
# 9            0.964072           0.909639         0.854111        0.119109
# 11           0.958084           0.915663         0.852127        0.121094
# 22           0.982036           0.879518         0.846067        0.126899
# 20           0.982036           0.867470         0.846043        0.120740
# 8            0.964072           0.861446         0.836051        0.116291
# 16           0.958084           0.861446         0.828067        0.122089
# 10           0.946108           0.861446         0.826071        0.115200
# 17           0.958084           0.855422         0.826059        0.121572
# 19           0.958084           0.849398         0.822055        0.123750
# 13           0.988024           1.000000         0.820359        0.245631
# 1            0.988024           1.000000         0.820359        0.245631
# 12           0.988024           1.000000         0.820359        0.245631
# 14           0.988024           1.000000         0.820359        0.245631
# 15           0.988024           1.000000         0.820359        0.245631
# 0            0.988024           0.993976         0.818351        0.244174
# 2            0.988024           0.993976         0.818351        0.244174
# 3            0.988024           0.993976         0.818351        0.244174
# 4            0.940120           0.867470         0.814107        0.130260
# 5            0.928144           0.843373         0.812063        0.109817
# 18           0.958084           0.843373         0.806075        0.141816
# 7            0.928144           0.831325         0.806051        0.111449
# 6            0.934132           0.849398         0.796107        0.139634
#
#     rank_test_score
# 21                1
# 23                2
# 9                 3
# 11                4
# 22                5
# 20                6
# 8                 7
# 16                8
# 10                9
# 17               10
# 19               11
# 13               12
# 1                12
# 12               12
# 14               12
# 15               12
# 0                17
# 2                17
# 3                17
# 4                20
# 5                21
# 18               22
# 7                23
# 6                24

# %%
forest_lb2_bparams = sorted_grid_forest.iloc[0]['params']

# %% [markdown]
# ### Random Forest - LB2 - Best Params

# %% [markdown]
# Fitted model

# %%
forest_lb2_best = RandomForestClassifier(**forest_lb2_bparams, **forest_const_params)

# %%
forest_lb2_best.fit(lb2_train, locs_lb2_train)
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='log_loss',
#                        max_depth=6, n_estimators=150, random_state=13,
#                        warm_start=True)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_pred = forest_lb2_best.predict(lb2_test)

# %%
forest_acc = acc_meas(locs_lb2_test, locs_pred, return_vals=True)
# Out:
# accuracy score:    0.8122605363984674
# f1 weighted score: 0.8129099446097544
# f1 micro score:    0.8122605363984674

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
forest_predframe = prediction_accuracy_frame(locs_lb2_test, locs_pred)
display(forest_predframe)
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak      Bayan Dzak            0.800000
#          L2        Bayan Dzak      Bayan Dzak            1.000000
#          L3        Bayan Dzak      Bayan Dzak            0.875000
# TS012    L1         Altan Uul       Altan Uul            0.974359
# TS020    L1            Nemegt          Nemegt            0.976744
# TS021    L1         Altan Uul          Nemegt            0.400000
# TS029    L1            Nemegt          Nemegt            0.698113
# TS030    L1    Tsagan Khushuu  Tsagan Khushuu            0.865385
#          L2    Tsagan Khushuu  Tsagan Khushuu            1.000000

# %%
forest_predframe.groupby('Locality')['PredictionAccuracy'].mean()
# Out:
# Locality
# Altan Uul         0.687179
# Bayan Dzak        0.891667
# Nemegt            0.837429
# Tsagan Khushuu    0.932692
# Name: PredictionAccuracy, dtype: float64

# %%
lb2_results['Predict_forest'] = lb2_results['Locality'] == locs_pred

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['forest']['lb2'] = {'conf_mat' : confusion_matrix(locs_lb2_test, locs_pred, normalize='true', labels=lb_label_order), 'labels' : lb_label_acronym}

# %% [markdown]
# ---

# %% [markdown]
# ### Random Forest - TB - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
forest_params = {
    'criterion' : ['gini'],
    'n_estimators' : [50, 100, 150],
    'max_depth' : [5, 6],
    'min_samples_leaf' : [1, 2],
    'max_features' : [None, 'log2', 'sqrt']
}

# %%
forest_const_params = {
    'random_state' : 13,
    'warm_start' : True,
    'class_weight' : 'balanced'
}

# %%
forest_tb_grid = GridSearchCV(estimator=RandomForestClassifier(**forest_const_params), param_grid=forest_params, cv=3, n_jobs=-1)

# %%
forest_tb_grid.fit(tb_train, locs_tb_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=13,
#                                               warm_start=True),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_depth': [5, 6],
#                          'max_features': [None, 'log2', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'n_estimators': [50, 100, 150]})

# %%
sorted_tb_grid_forest = grid_results_view(forest_tb_grid)

# %%
forest_tb_bparams = sorted_grid_forest.iloc[0]['params']

# %% [markdown]
# ### Random Forest - TB - Best Params

# %% [markdown]
# Fitted model

# %%
forest_tb_best = RandomForestClassifier(**forest_tb_bparams, **forest_const_params)

# %%
forest_tb_best.fit(tb_train, locs_tb_train)
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='log_loss',
#                        max_depth=6, n_estimators=150, random_state=13,
#                        warm_start=True)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_tb_pred = forest_tb_best.predict(tb_test)

# %%
forest_acc = acc_meas(locs_tb_test, locs_tb_pred, return_vals=True)
# Out:
# accuracy score:    0.30864197530864196
# f1 weighted score: 0.3281121399176955
# f1 micro score:    0.30864197530864196

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
forest_predframe = prediction_accuracy_frame(locs_tb_test, locs_tb_pred)
display(forest_predframe)
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR001    L1          Toogreek        Toogreek            1.000000
# SF003    L1         Altan Uul          Nemegt            0.000000
#          L2         Altan Uul  Tsagan Khushuu            0.066667
#          L3         Altan Uul  Tsagan Khushuu            0.076923
#          L4         Altan Uul          Nemegt            0.000000
# TF028    L1            Nemegt          Nemegt            1.000000
#          L2            Nemegt          Nemegt            1.000000
#          L3            Nemegt       Altan Uul            0.033333
#          L4            Nemegt       Altan Uul            0.045455
# TS027    L1    Tsagan Khushuu          Nemegt            0.000000
#          L2    Tsagan Khushuu          Nemegt            0.000000
#          L3    Tsagan Khushuu          Nemegt            0.000000

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['forest']['tb'] = {'conf_mat' : confusion_matrix(locs_tb_test, locs_tb_pred, normalize='true', labels=tb_label_order), 'labels' : tb_label_acronym}

# %% [markdown]
# ---

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier

# %%
loc2num = {name : num for num, name in enumerate(lb_label_order)}
num2loc = {num : name for num, name in enumerate(lb_label_order)}

# %%
locs_lb1_train_num = locs_lb1_train.replace(loc2num)
locs_lb1_test_num = locs_lb1_test.replace(loc2num)

# %%
locs_lb2_train_num = locs_lb2_train.replace(loc2num)
locs_lb2_test_num = locs_lb2_test.replace(loc2num)

# %%
xgb = XGBClassifier(n_estimators=100, random_state=13, enable_categorical=True)

# %%
xgb.fit(lb1_train, locs_lb1_train_num)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
locs_pred, acc_score, predframe = model_predictions(xgb, lb1_test, locs_lb1_test_num)

# %%
predframe.explode('PredictionMode').replace({'Locality' : num2loc, 'PredictionMode' : num2loc})
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak          Nemegt            0.000000
#          L2        Bayan Dzak          Nemegt            0.000000
#          L3        Bayan Dzak          Nemegt            0.000000
# TS012    L1         Altan Uul       Altan Uul            0.974359
# TS020    L1            Nemegt          Nemegt            0.976744
# TS021    L1         Altan Uul       Altan Uul            0.857143
# TS022    L1         Altan Uul          Nemegt            0.062500
#          L2         Altan Uul          Nemegt            0.000000
# TS029    L1            Nemegt          Nemegt            0.962264
# TS030    L1    Tsagan Khushuu  Tsagan Khushuu            0.807692
#          L2    Tsagan Khushuu  Tsagan Khushuu            0.583333

# %% [markdown]
# ### XGB - LB1 - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
xgb_params = {
    'n_estimators' : [75, 100],
    'max_depth' : [3, 5],
    'max_leaves' : [2, 4],
    'tree_method' : ['hist'],
    'learning_rate' : [0.1, 0.2, 0.7, 0.9]
}

# %%
xgb_const = {
    'abooster' : 'gblinear',
    'random_stae' : 13
}

# %%
xgb_grid = GridSearchCV(XGBClassifier(**xgb_const), param_grid=xgb_params, cv=3, n_jobs=-1)

# %%
xgb_grid.fit(lb1_train, locs_lb1_train_num)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(abooster='gblinear', base_score=None,
#                                      booster=None, callbacks=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2, 0.7, 0.9],
#                          'max_depth': [3, 5], 'max_leaves': [2, 4],
#                          'n_estimators': [75, 100], 'tree_method': ['hist']})

# %%
sorted_grid_xboost = grid_results_view(xgb_grid)

# %%
sorted_grid_xboost
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 31       0.096765      0.031816         0.006838        0.000233
# 27       0.137472      0.035917         0.007851        0.001028
# 23       0.163877      0.030679         0.010852        0.001856
# 19       0.169981      0.033046         0.014019        0.001461
# 26       0.134134      0.024552         0.010506        0.002487
# 22       0.144053      0.028173         0.013511        0.000409
# 18       0.141620      0.027953         0.014029        0.000409
# 30       0.101120      0.011267         0.008679        0.002349
# 11       0.243736      0.051559         0.014857        0.001670
# 15       0.231703      0.044929         0.014842        0.001832
# 13       0.150441      0.011791         0.013518        0.001420
# 9        0.140773      0.008222         0.015510        0.004632
# 7        0.268539      0.037761         0.014700        0.001715
# 3        0.228265      0.013303         0.008003        0.001635
# 10       0.197294      0.028411         0.013510        0.000408
# 14       0.209007      0.023324         0.013856        0.001039
# 29       0.103107      0.023366         0.008504        0.001779
# 28       0.102592      0.014624         0.011846        0.000634
# 25       0.126301      0.014125         0.011173        0.001035
# 24       0.110307      0.010413         0.013844        0.000224
# 21       0.133383      0.014599         0.013367        0.000225
# 20       0.107880      0.007208         0.012876        0.000845
# 17       0.138109      0.010159         0.012367        0.000848
# 16       0.112334      0.009526         0.012032        0.000411
# 12       0.118645      0.010938         0.014188        0.001701
# 8        0.124213      0.002055         0.011382        0.000472
# 6        0.213140      0.020220         0.013336        0.001247
# 2        0.203260      0.008261         0.007668        0.000471
# 1        0.158251      0.006129         0.011670        0.000472
# 5        0.132053      0.015625         0.011684        0.004131
# 4        0.132581      0.006684         0.010669        0.000471
# 0        0.129219      0.001187         0.011855        0.001249
#
#     param_learning_rate  param_max_depth  param_max_leaves  \
# 31                  0.9                5                 4
# 27                  0.9                3                 4
# 23                  0.7                5                 4
# 19                  0.7                3                 4
# 26                  0.9                3                 4
# 22                  0.7                5                 4
# 18                  0.7                3                 4
# 30                  0.9                5                 4
# 11                  0.2                3                 4
# 15                  0.2                5                 4
# 13                  0.2                5                 2
# 9                   0.2                3                 2
# 7                   0.1                5                 4
# 3                   0.1                3                 4
# 10                  0.2                3                 4
# 14                  0.2                5                 4
# 29                  0.9                5                 2
# 28                  0.9                5                 2
# 25                  0.9                3                 2
# 24                  0.9                3                 2
# 21                  0.7                5                 2
# 20                  0.7                5                 2
# 17                  0.7                3                 2
# 16                  0.7                3                 2
# 12                  0.2                5                 2
# 8                   0.2                3                 2
# 6                   0.1                5                 4
# 2                   0.1                3                 4
# 1                   0.1                3                 2
# 5                   0.1                5                 2
# 4                   0.1                5                 2
# 0                   0.1                3                 2
#
#     param_n_estimators param_tree_method  \
# 31                 100              hist
# 27                 100              hist
# 23                 100              hist
# 19                 100              hist
# 26                  75              hist
# 22                  75              hist
# 18                  75              hist
# 30                  75              hist
# 11                 100              hist
# 15                 100              hist
# 13                 100              hist
# 9                  100              hist
# 7                  100              hist
# 3                  100              hist
# 10                  75              hist
# 14                  75              hist
# 29                 100              hist
# 28                  75              hist
# 25                 100              hist
# 24                  75              hist
# 21                 100              hist
# 20                  75              hist
# 17                 100              hist
# 16                  75              hist
# 12                  75              hist
# 8                   75              hist
# 6                   75              hist
# 2                   75              hist
# 1                  100              hist
# 5                  100              hist
# 4                   75              hist
# 0                   75              hist
#
#                                                params  split0_test_score  \
# 31  {'learning_rate': 0.9, 'max_depth': 5, 'max_le...           0.697436
# 27  {'learning_rate': 0.9, 'max_depth': 3, 'max_le...           0.697436
# 23  {'learning_rate': 0.7, 'max_depth': 5, 'max_le...           0.697436
# 19  {'learning_rate': 0.7, 'max_depth': 3, 'max_le...           0.697436
# 26  {'learning_rate': 0.9, 'max_depth': 3, 'max_le...           0.697436
# 22  {'learning_rate': 0.7, 'max_depth': 5, 'max_le...           0.697436
# 18  {'learning_rate': 0.7, 'max_depth': 3, 'max_le...           0.697436
# 30  {'learning_rate': 0.9, 'max_depth': 5, 'max_le...           0.697436
# 11  {'learning_rate': 0.2, 'max_depth': 3, 'max_le...           0.702564
# 15  {'learning_rate': 0.2, 'max_depth': 5, 'max_le...           0.702564
# 13  {'learning_rate': 0.2, 'max_depth': 5, 'max_le...           0.692308
# 9   {'learning_rate': 0.2, 'max_depth': 3, 'max_le...           0.692308
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'max_le...           0.697436
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'max_le...           0.697436
# 10  {'learning_rate': 0.2, 'max_depth': 3, 'max_le...           0.702564
# 14  {'learning_rate': 0.2, 'max_depth': 5, 'max_le...           0.702564
# 29  {'learning_rate': 0.9, 'max_depth': 5, 'max_le...           0.692308
# 28  {'learning_rate': 0.9, 'max_depth': 5, 'max_le...           0.692308
# 25  {'learning_rate': 0.9, 'max_depth': 3, 'max_le...           0.692308
# 24  {'learning_rate': 0.9, 'max_depth': 3, 'max_le...           0.692308
# 21  {'learning_rate': 0.7, 'max_depth': 5, 'max_le...           0.692308
# 20  {'learning_rate': 0.7, 'max_depth': 5, 'max_le...           0.692308
# 17  {'learning_rate': 0.7, 'max_depth': 3, 'max_le...           0.692308
# 16  {'learning_rate': 0.7, 'max_depth': 3, 'max_le...           0.692308
# 12  {'learning_rate': 0.2, 'max_depth': 5, 'max_le...           0.692308
# 8   {'learning_rate': 0.2, 'max_depth': 3, 'max_le...           0.692308
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'max_le...           0.697436
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'max_le...           0.697436
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'max_le...           0.687179
# 5   {'learning_rate': 0.1, 'max_depth': 5, 'max_le...           0.687179
# 4   {'learning_rate': 0.1, 'max_depth': 5, 'max_le...           0.687179
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'max_le...           0.687179
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 31           0.994845           0.994845         0.895709        0.140200
# 27           0.994845           0.994845         0.895709        0.140200
# 23           0.989691           1.000000         0.895709        0.140263
# 19           0.989691           1.000000         0.895709        0.140263
# 26           0.989691           0.994845         0.893991        0.139001
# 22           0.989691           0.994845         0.893991        0.139001
# 18           0.989691           0.994845         0.893991        0.139001
# 30           0.989691           0.994845         0.893991        0.139001
# 11           0.989691           0.989691         0.893982        0.135353
# 15           0.989691           0.989691         0.893982        0.135353
# 13           1.000000           0.984536         0.892281        0.141544
# 9            1.000000           0.984536         0.892281        0.141544
# 7            0.989691           0.989691         0.892272        0.137770
# 3            0.989691           0.989691         0.892272        0.137770
# 10           0.989691           0.984536         0.892264        0.134154
# 14           0.989691           0.984536         0.892264        0.134154
# 29           0.994845           0.984536         0.890563        0.140251
# 28           0.994845           0.984536         0.890563        0.140251
# 25           0.994845           0.984536         0.890563        0.140251
# 24           0.994845           0.984536         0.890563        0.140251
# 21           0.994845           0.984536         0.890563        0.140251
# 20           0.994845           0.984536         0.890563        0.140251
# 17           0.994845           0.984536         0.890563        0.140251
# 16           0.994845           0.984536         0.890563        0.140251
# 12           0.994845           0.984536         0.890563        0.140251
# 8            0.994845           0.984536         0.890563        0.140251
# 6            0.989691           0.984536         0.890554        0.136571
# 2            0.989691           0.984536         0.890554        0.136571
# 1            0.994845           0.984536         0.888854        0.142667
# 5            0.994845           0.984536         0.888854        0.142667
# 4            0.989691           0.984536         0.887135        0.141406
# 0            0.989691           0.984536         0.887135        0.141406
#
#     rank_test_score
# 31                1
# 27                1
# 23                1
# 19                1
# 26                5
# 22                5
# 18                5
# 30                5
# 11                9
# 15                9
# 13               11
# 9                11
# 7                13
# 3                13
# 10               15
# 14               15
# 29               17
# 28               17
# 25               17
# 24               17
# 21               17
# 20               17
# 17               17
# 16               17
# 12               17
# 8                17
# 6                27
# 2                27
# 1                29
# 5                29
# 4                31
# 0                31

# %%
xboost_lb1_bparams = sorted_grid_xboost.iloc[0]['params']

# %% [markdown]
# ### XGB - LB1 - Best Params

# %% [markdown]
# Fitted model

# %%
xboost_lb1_best = XGBClassifier(**xboost_lb1_bparams, **xgb_const)

# %%
xboost_lb1_best.fit(lb1_train, locs_lb1_train_num)
# Out:
# XGBClassifier(abooster='gblinear', base_score=None, booster=None,
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.9, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=4,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_pred, acc_score, predframe = model_predictions(xboost_lb1_best, lb1_test, locs_lb1_test_num)

# %%
locs_pred_names = pd.Series(locs_pred).replace(num2loc)

# %%
acc_meas(locs_lb1_test, locs_pred_names)
# Out:
# accuracy score:    0.5952380952380952
# f1 weighted score: 0.57206972786074
# f1 micro score:    0.5952380952380952

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
xboost_predframe = predframe.explode('PredictionMode').replace({'Locality' : num2loc, 'PredictionMode' : num2loc})
display(xboost_predframe)
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak          Nemegt            0.000000
#          L2        Bayan Dzak          Nemegt            0.000000
#          L3        Bayan Dzak          Nemegt            0.000000
# TS012    L1         Altan Uul       Altan Uul            0.974359
# TS020    L1            Nemegt          Nemegt            0.976744
# TS021    L1         Altan Uul       Altan Uul            0.828571
# TS022    L1         Altan Uul          Nemegt            0.000000
#          L2         Altan Uul          Nemegt            0.000000
# TS029    L1            Nemegt          Nemegt            0.490566
# TS030    L1    Tsagan Khushuu  Tsagan Khushuu            0.692308
#          L2    Tsagan Khushuu       Altan Uul            0.333333

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['xboost']['lb1'] = {'conf_mat' : confusion_matrix(locs_lb1_test_num, locs_pred, normalize='true'), 'labels' : [locdict[j] for j in [num2loc[i] for i in xboost_lb1_best.classes_]]}

# %% [markdown]
# ---

# %% [markdown]
# ### XGB - LB2 - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
xgb_params = {
    'n_estimators' : [75, 100],
    'max_depth' : [3, 5],
    'max_leaves' : [2, 4],
    'tree_method' : ['hist'],
    'learning_rate' : [0.1, 0.2, 0.7, 0.9]
}

# %%
xgb_const = {
    'abooster' : 'gblinear',
    'random_stae' : 13
}

# %%
xgb_grid = GridSearchCV(XGBClassifier(**xgb_const), param_grid=xgb_params, cv=3, n_jobs=-1)

# %%
xgb_grid.fit(lb2_train, locs_lb2_train_num)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(abooster='gblinear', base_score=None,
#                                      booster=None, callbacks=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2, 0.7, 0.9],
#                          'max_depth': [3, 5], 'max_leaves': [2, 4],
#                          'n_estimators': [75, 100], 'tree_method': ['hist']})

# %%
sorted_grid_xboost = grid_results_view(xgb_grid)

# %%
sorted_grid_xboost
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 23       0.165081      0.037322         0.009842        0.002019
# 22       0.151908      0.031406         0.013191        0.001175
# 19       0.175772      0.043922         0.012684        0.000848
# 18       0.145541      0.032532         0.012189        0.001332
# 15       0.230661      0.041742         0.012697        0.000853
# 11       0.235672      0.045860         0.013191        0.000632
# 10       0.205824      0.027461         0.017523        0.004312
# 14       0.194591      0.035387         0.013187        0.001298
# 20       0.108202      0.011175         0.012518        0.001410
# 16       0.122477      0.018878         0.015200        0.001939
# 9        0.153636      0.014179         0.013175        0.000245
# 13       0.156235      0.015706         0.013857        0.001559
# 27       0.139698      0.035749         0.008508        0.002129
# 26       0.133226      0.024584         0.011017        0.002133
# 30       0.111635      0.018778         0.007669        0.000941
# 31       0.092757      0.027507         0.006528        0.000415
# 7        0.274034      0.034239         0.012680        0.001233
# 6        0.229651      0.023009         0.013014        0.001431
# 3        0.269119      0.040390         0.011669        0.000471
# 2        0.222395      0.027806         0.012348        0.000952
# 8        0.117430      0.014692         0.012336        0.000472
# 17       0.132207      0.014224         0.018188        0.006319
# 5        0.158909      0.013482         0.012681        0.001442
# 21       0.135016      0.020964         0.014381        0.001699
# 1        0.139640      0.011900         0.011336        0.000473
# 12       0.133476      0.016015         0.013014        0.000831
# 4        0.124029      0.007259         0.012669        0.002358
# 0        0.110692      0.002625         0.011002        0.000002
# 24       0.121342      0.020237         0.013530        0.001201
# 28       0.110535      0.007036         0.011859        0.000633
# 25       0.124201      0.011785         0.015186        0.006650
# 29       0.111825      0.018420         0.009508        0.001880
#
#     param_learning_rate  param_max_depth  param_max_leaves  \
# 23                  0.7                5                 4
# 22                  0.7                5                 4
# 19                  0.7                3                 4
# 18                  0.7                3                 4
# 15                  0.2                5                 4
# 11                  0.2                3                 4
# 10                  0.2                3                 4
# 14                  0.2                5                 4
# 20                  0.7                5                 2
# 16                  0.7                3                 2
# 9                   0.2                3                 2
# 13                  0.2                5                 2
# 27                  0.9                3                 4
# 26                  0.9                3                 4
# 30                  0.9                5                 4
# 31                  0.9                5                 4
# 7                   0.1                5                 4
# 6                   0.1                5                 4
# 3                   0.1                3                 4
# 2                   0.1                3                 4
# 8                   0.2                3                 2
# 17                  0.7                3                 2
# 5                   0.1                5                 2
# 21                  0.7                5                 2
# 1                   0.1                3                 2
# 12                  0.2                5                 2
# 4                   0.1                5                 2
# 0                   0.1                3                 2
# 24                  0.9                3                 2
# 28                  0.9                5                 2
# 25                  0.9                3                 2
# 29                  0.9                5                 2
#
#     param_n_estimators param_tree_method  \
# 23                 100              hist
# 22                  75              hist
# 19                 100              hist
# 18                  75              hist
# 15                 100              hist
# 11                 100              hist
# 10                  75              hist
# 14                  75              hist
# 20                  75              hist
# 16                  75              hist
# 9                  100              hist
# 13                 100              hist
# 27                 100              hist
# 26                  75              hist
# 30                  75              hist
# 31                 100              hist
# 7                  100              hist
# 6                   75              hist
# 3                  100              hist
# 2                   75              hist
# 8                   75              hist
# 17                 100              hist
# 5                  100              hist
# 21                 100              hist
# 1                  100              hist
# 12                  75              hist
# 4                   75              hist
# 0                   75              hist
# 24                  75              hist
# 28                  75              hist
# 25                 100              hist
# 29                 100              hist
#
#                                                params  split0_test_score  \
# 23  {'learning_rate': 0.7, 'max_depth': 5, 'max_le...           0.652695
# 22  {'learning_rate': 0.7, 'max_depth': 5, 'max_le...           0.652695
# 19  {'learning_rate': 0.7, 'max_depth': 3, 'max_le...           0.652695
# 18  {'learning_rate': 0.7, 'max_depth': 3, 'max_le...           0.652695
# 15  {'learning_rate': 0.2, 'max_depth': 5, 'max_le...           0.652695
# 11  {'learning_rate': 0.2, 'max_depth': 3, 'max_le...           0.652695
# 10  {'learning_rate': 0.2, 'max_depth': 3, 'max_le...           0.652695
# 14  {'learning_rate': 0.2, 'max_depth': 5, 'max_le...           0.652695
# 20  {'learning_rate': 0.7, 'max_depth': 5, 'max_le...           0.640719
# 16  {'learning_rate': 0.7, 'max_depth': 3, 'max_le...           0.640719
# 9   {'learning_rate': 0.2, 'max_depth': 3, 'max_le...           0.640719
# 13  {'learning_rate': 0.2, 'max_depth': 5, 'max_le...           0.640719
# 27  {'learning_rate': 0.9, 'max_depth': 3, 'max_le...           0.652695
# 26  {'learning_rate': 0.9, 'max_depth': 3, 'max_le...           0.652695
# 30  {'learning_rate': 0.9, 'max_depth': 5, 'max_le...           0.652695
# 31  {'learning_rate': 0.9, 'max_depth': 5, 'max_le...           0.652695
# 7   {'learning_rate': 0.1, 'max_depth': 5, 'max_le...           0.652695
# 6   {'learning_rate': 0.1, 'max_depth': 5, 'max_le...           0.652695
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'max_le...           0.652695
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'max_le...           0.652695
# 8   {'learning_rate': 0.2, 'max_depth': 3, 'max_le...           0.640719
# 17  {'learning_rate': 0.7, 'max_depth': 3, 'max_le...           0.640719
# 5   {'learning_rate': 0.1, 'max_depth': 5, 'max_le...           0.640719
# 21  {'learning_rate': 0.7, 'max_depth': 5, 'max_le...           0.640719
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'max_le...           0.640719
# 12  {'learning_rate': 0.2, 'max_depth': 5, 'max_le...           0.640719
# 4   {'learning_rate': 0.1, 'max_depth': 5, 'max_le...           0.634731
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'max_le...           0.634731
# 24  {'learning_rate': 0.9, 'max_depth': 3, 'max_le...           0.628743
# 28  {'learning_rate': 0.9, 'max_depth': 5, 'max_le...           0.628743
# 25  {'learning_rate': 0.9, 'max_depth': 3, 'max_le...           0.628743
# 29  {'learning_rate': 0.9, 'max_depth': 5, 'max_le...           0.628743
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 23           0.994012           0.993976         0.880227        0.160890
# 22           0.994012           0.993976         0.880227        0.160890
# 19           0.994012           0.993976         0.880227        0.160890
# 18           0.994012           0.993976         0.880227        0.160890
# 15           0.988024           0.993976         0.878231        0.159497
# 11           0.988024           0.993976         0.878231        0.159497
# 10           0.988024           0.987952         0.876223        0.158059
# 14           0.988024           0.987952         0.876223        0.158059
# 20           0.994012           0.981928         0.872219        0.163770
# 16           0.994012           0.981928         0.872219        0.163770
# 9            0.994012           0.981928         0.872219        0.163770
# 13           0.994012           0.981928         0.872219        0.163770
# 27           0.988024           0.975904         0.872207        0.155298
# 26           0.988024           0.975904         0.872207        0.155298
# 30           0.988024           0.975904         0.872207        0.155298
# 31           0.988024           0.975904         0.872207        0.155298
# 7            0.988024           0.975904         0.872207        0.155298
# 6            0.988024           0.975904         0.872207        0.155298
# 3            0.988024           0.975904         0.872207        0.155298
# 2            0.988024           0.975904         0.872207        0.155298
# 8            0.988024           0.981928         0.870223        0.162304
# 17           0.988024           0.981928         0.870223        0.162304
# 5            0.988024           0.981928         0.870223        0.162304
# 21           0.988024           0.981928         0.870223        0.162304
# 1            0.988024           0.981928         0.870223        0.162304
# 12           0.988024           0.981928         0.870223        0.162304
# 4            0.988024           0.981928         0.868227        0.165126
# 0            0.988024           0.981928         0.868227        0.165126
# 24           0.994012           0.975904         0.866219        0.168084
# 28           0.994012           0.975904         0.866219        0.168084
# 25           0.982036           0.975904         0.862227        0.165118
# 29           0.982036           0.975904         0.862227        0.165118
#
#     rank_test_score
# 23                1
# 22                1
# 19                1
# 18                1
# 15                5
# 11                5
# 10                7
# 14                7
# 20                9
# 16                9
# 9                 9
# 13                9
# 27               13
# 26               13
# 30               13
# 31               13
# 7                13
# 6                13
# 3                13
# 2                13
# 8                21
# 17               21
# 5                21
# 21               21
# 1                21
# 12               21
# 4                27
# 0                27
# 24               29
# 28               29
# 25               31
# 29               31

# %%
xboost_lb2_bparams = sorted_grid_xboost.iloc[0]['params']

# %% [markdown]
# ### XGB - LB2 - Best Params

# %% [markdown]
# Fitted model

# %%
xboost_lb2_best = XGBClassifier(**xboost_lb2_bparams, **xgb_const)

# %%
xboost_lb2_best.fit(lb2_train, locs_lb2_train_num)
# Out:
# XGBClassifier(abooster='gblinear', base_score=None, booster=None,
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.7, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=4,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_pred, acc_score, predframe = model_predictions(xboost_lb2_best, lb2_test, locs_lb2_test_num)

# %%
locs_pred_names = pd.Series(locs_pred).replace(num2loc)

# %%
acc_meas(locs_lb2_test, locs_pred_names)
# Out:
# accuracy score:    0.7662835249042146
# f1 weighted score: 0.724001632047609
# f1 micro score:    0.7662835249042146

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
xboost_predframe = predframe.explode('PredictionMode').replace({'Locality' : num2loc, 'PredictionMode' : num2loc})
display(xboost_predframe)
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak          Nemegt            0.000000
#          L2        Bayan Dzak          Nemegt            0.000000
#          L3        Bayan Dzak          Nemegt            0.000000
# TS012    L1         Altan Uul       Altan Uul            0.974359
# TS020    L1            Nemegt          Nemegt            0.976744
# TS021    L1         Altan Uul       Altan Uul            0.771429
# TS029    L1            Nemegt          Nemegt            0.886792
# TS030    L1    Tsagan Khushuu  Tsagan Khushuu            0.750000
#          L2    Tsagan Khushuu  Tsagan Khushuu            0.583333

# %%
pred_xgb = locs_lb2_test_num == locs_pred

# %%
lb2_results['Predict_xboost'] = lb2_results['Locality'] == locs_pred

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['xboost']['lb2'] = {'conf_mat' : confusion_matrix(locs_lb2_test_num, locs_pred, normalize='true'), 'labels' : [locdict[j] for j in [num2loc[i] for i in xboost_lb2_best.classes_]]}

# %% [markdown]
# ---

# %% [markdown]
# ### XGB - TB - Hyperparamterers

# %% [markdown]
# XGBoost accepts numeric classes only, therefore, the classes are changed to numeric values for `loc_tb_2num` dictionary. The second one (`num_tb_2loc` does the reverse operation)

# %%
loc_tb_2num = {name : num for num, name in enumerate(tb_label_order)}
num_tb_2loc = {num : name for num, name in enumerate(tb_label_order)}

# %%
locs_tb_train_num = locs_tb_train.replace(loc_tb_2num)
locs_tb_test_num = locs_tb_test.replace(loc_tb_2num)

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
xgb_tb_params = {
    'n_estimators' : [75, 100],
    'max_depth' : [3, 5],
    'max_leaves' : [2, 4],
    'tree_method' : ['hist'],
    'learning_rate' : [0.1, 0.2, 0.7, 0.9]
}

# %%
xgb_tb_const = {
    'abooster' : 'gblinear',
    'random_stae' : 13
}

# %%
xgb_grid_tb = GridSearchCV(XGBClassifier(**xgb_tb_const), param_grid=xgb_tb_params, cv=3, n_jobs=-1)

# %%
xgb_grid_tb.fit(tb_train, locs_tb_train_num)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(abooster='gblinear', base_score=None,
#                                      booster=None, callbacks=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2, 0.7, 0.9],
#                          'max_depth': [3, 5], 'max_leaves': [2, 4],
#                          'n_estimators': [75, 100], 'tree_method': ['hist']})

# %%
sorted_tb_grid_xboost = grid_results_view(xgb_grid_tb)

# %%
xboost_tb_bparams = sorted_tb_grid_xboost.iloc[0]['params']

# %% [markdown]
# ### XGB - TB - Best Params

# %% [markdown]
# Fitted model

# %%
xboost_tb_best = XGBClassifier(**xboost_tb_bparams, **xgb_const)

# %%
xboost_tb_best.fit(tb_train, locs_tb_train_num)
# Out:
# XGBClassifier(abooster='gblinear', base_score=None, booster=None,
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=2,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=75, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_tb_num_pred, acc_score, predframe = model_predictions(xboost_tb_best, tb_test, locs_tb_test_num)

# %%
acc_meas(locs_tb_test_num, locs_tb_num_pred)
# Out:
# accuracy score:    0.07407407407407407
# f1 weighted score: 0.07213930348258707
# f1 micro score:    0.07407407407407407

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
xboost_tb_predframe = predframe.explode('PredictionMode').replace({'Locality' : num_tb_2loc, 'PredictionMode' : num_tb_2loc})
display(xboost_tb_predframe)
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR001    L1          Toogreek        Toogreek            1.000000
# SF003    L1         Altan Uul          Nemegt            0.000000
#          L1         Altan Uul  Tsagan Khushuu            0.000000
#          L2         Altan Uul  Tsagan Khushuu            0.066667
#          L3         Altan Uul  Tsagan Khushuu            0.000000
#          L4         Altan Uul  Tsagan Khushuu            0.000000
# TF028    L1            Nemegt       Altan Uul            0.000000
#          L2            Nemegt       Altan Uul            0.000000
#          L3            Nemegt       Altan Uul            0.000000
#          L4            Nemegt       Altan Uul            0.000000
# TS027    L1    Tsagan Khushuu          Nemegt            0.000000
#          L2    Tsagan Khushuu          Nemegt            0.000000
#          L3    Tsagan Khushuu          Nemegt            0.000000

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['xboost']['tb'] = {'conf_mat' : confusion_matrix(locs_tb_test_num, locs_tb_num_pred, normalize='true'), 'labels' : [locdict[j] for j in [num_tb_2loc[i] for i in xboost_tb_best.classes_]]}

# %% [markdown]
# --- --- ---

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
aboost = AdaBoostClassifier(estimator=DecisionTreeClassifier(), random_state=13)

# %%
aboost.fit(lb1_train, locs_lb1_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), random_state=13)

# %%
locs_pred, acc_score, predframe = model_predictions(aboost, lb1_test, locs_lb1_test)

# %%
acc_meas(locs_lb1_test, locs_pred)
# Out:
# accuracy score:    0.6870748299319728
# f1 weighted score: 0.6761105606447565
# f1 micro score:    0.6870748299319728

# %%
predframe
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak      Bayan Dzak            1.000000
#          L2        Bayan Dzak      Bayan Dzak            1.000000
#          L3        Bayan Dzak      Bayan Dzak            1.000000
# TS012    L1         Altan Uul       Altan Uul            0.769231
# TS020    L1            Nemegt          Nemegt            0.511628
# TS021    L1         Altan Uul       Altan Uul            0.514286
# TS022    L1         Altan Uul          Nemegt            0.375000
#          L2         Altan Uul          Nemegt            0.235294
# TS029    L1            Nemegt          Nemegt            0.584906
# TS030    L1    Tsagan Khushuu  Tsagan Khushuu            1.000000
#          L2    Tsagan Khushuu  Tsagan Khushuu            1.000000

# %% [markdown]
# ### AdaBoost - LB1 - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
aboost_params = {
    'algorithm' : ['SAMME', 'SAMME.R'],
    'n_estimators' : [50, 75],
    'learning_rate' : [1.0, 2.0],
    'estimator' : [DecisionTreeClassifier(max_depth=2), 
                   DecisionTreeClassifier(max_depth=3),
                   DecisionTreeClassifier(max_depth=4)]
}

# %%
aboost_grid = GridSearchCV(AdaBoostClassifier(DecisionTreeClassifier(), random_state=13), param_grid=aboost_params, cv=3, n_jobs=-1)

# %%
aboost_grid.fit(lb1_train, locs_lb1_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(),
#                                           random_state=13),
#              n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'estimator': [DecisionTreeClassifier(max_depth=2),
#                                        DecisionTreeClassifier(max_depth=3),
#                                        DecisionTreeClassifier(max_depth=4)],
#                          'learning_rate': [1.0, 2.0],
#                          'n_estimators': [50, 75]})

# %%
sorted_grid_aboost = grid_results_view(aboost_grid)

# %%
sorted_grid_aboost
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 23       0.321224      0.213707         0.008357        0.003810
# 22       0.254768      0.172034         0.008002        0.003743
# 20       0.283339      0.181594         0.010506        0.005346
# 17       0.317208      0.226503         0.010882        0.007393
# 10       0.261343      0.177724         0.011676        0.007034
# 21       0.368355      0.254108         0.008675        0.004010
# 19       0.301383      0.211453         0.011022        0.005731
# 4        0.224200      0.153189         0.011008        0.005664
# 18       0.239775      0.154137         0.010347        0.005257
# 16       0.251876      0.166795         0.011011        0.004962
# 11       0.371604      0.257207         0.012351        0.007158
# 5        0.354321      0.244291         0.013688        0.008274
# 9        0.414200      0.286762         0.017522        0.010716
# 8        0.276963      0.189524         0.010185        0.005081
# 7        0.344402      0.236797         0.017024        0.010214
# 6        0.233071      0.157409         0.013021        0.007270
# 1        0.393320      0.008644         0.021339        0.001248
# 15       0.420520      0.024599         0.018028        0.003575
# 0        0.251160      0.001085         0.015197        0.001020
# 14       0.304089      0.014292         0.014516        0.000415
# 2        0.255358      0.001245         0.014520        0.000815
# 13       0.437073      0.013042         0.020358        0.000956
# 12       0.305258      0.007971         0.014353        0.000228
# 3        0.404992      0.011816         0.019677        0.000627
#
#    param_algorithm                      param_estimator  param_learning_rate  \
# 23         SAMME.R  DecisionTreeClassifier(max_depth=4)                  2.0
# 22         SAMME.R  DecisionTreeClassifier(max_depth=4)                  2.0
# 20         SAMME.R  DecisionTreeClassifier(max_depth=4)                  1.0
# 17         SAMME.R  DecisionTreeClassifier(max_depth=3)                  1.0
# 10           SAMME  DecisionTreeClassifier(max_depth=4)                  2.0
# 21         SAMME.R  DecisionTreeClassifier(max_depth=4)                  1.0
# 19         SAMME.R  DecisionTreeClassifier(max_depth=3)                  2.0
# 4            SAMME  DecisionTreeClassifier(max_depth=3)                  1.0
# 18         SAMME.R  DecisionTreeClassifier(max_depth=3)                  2.0
# 16         SAMME.R  DecisionTreeClassifier(max_depth=3)                  1.0
# 11           SAMME  DecisionTreeClassifier(max_depth=4)                  2.0
# 5            SAMME  DecisionTreeClassifier(max_depth=3)                  1.0
# 9            SAMME  DecisionTreeClassifier(max_depth=4)                  1.0
# 8            SAMME  DecisionTreeClassifier(max_depth=4)                  1.0
# 7            SAMME  DecisionTreeClassifier(max_depth=3)                  2.0
# 6            SAMME  DecisionTreeClassifier(max_depth=3)                  2.0
# 1            SAMME  DecisionTreeClassifier(max_depth=2)                  1.0
# 15         SAMME.R  DecisionTreeClassifier(max_depth=2)                  2.0
# 0            SAMME  DecisionTreeClassifier(max_depth=2)                  1.0
# 14         SAMME.R  DecisionTreeClassifier(max_depth=2)                  2.0
# 2            SAMME  DecisionTreeClassifier(max_depth=2)                  2.0
# 13         SAMME.R  DecisionTreeClassifier(max_depth=2)                  1.0
# 12         SAMME.R  DecisionTreeClassifier(max_depth=2)                  1.0
# 3            SAMME  DecisionTreeClassifier(max_depth=2)                  2.0
#
#     param_n_estimators                                             params  \
# 23                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 22                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 20                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 17                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 10                  50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 21                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 19                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 4                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 18                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 16                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 11                  75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 5                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 9                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 8                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 7                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 6                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 1                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 15                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 0                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 14                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 2                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 13                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 12                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 3                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 23           0.728205           1.000000           1.000000         0.909402
# 22           0.728205           0.994845           1.000000         0.907683
# 20           0.728205           0.984536           1.000000         0.904247
# 17           0.728205           0.984536           1.000000         0.904247
# 10           0.728205           0.984536           1.000000         0.904247
# 21           0.728205           0.979381           1.000000         0.902529
# 19           0.728205           0.994845           0.984536         0.902529
# 4            0.728205           0.984536           0.994845         0.902529
# 18           0.728205           0.989691           0.989691         0.902529
# 16           0.728205           0.974227           1.000000         0.900811
# 11           0.728205           0.969072           1.000000         0.899092
# 5            0.728205           0.974227           0.994845         0.899092
# 9            0.728205           0.989691           0.974227         0.897374
# 8            0.728205           0.974227           0.984536         0.895656
# 7            0.728205           0.974227           0.984536         0.895656
# 6            0.728205           0.969072           0.984536         0.893938
# 1            0.712821           0.984536           0.979381         0.892246
# 15           0.676923           0.943299           0.989691         0.869971
# 0            0.712821           0.974227           0.922680         0.869909
# 14           0.666667           0.932990           0.984536         0.861397
# 2            0.635897           0.927835           0.984536         0.849423
# 13           0.558974           0.984536           0.989691         0.844400
# 12           0.569231           0.948454           0.979381         0.832355
# 3            0.594872           0.922680           0.969072         0.828875
#
#     std_test_score  rank_test_score
# 23        0.128125                1
# 22        0.126928                2
# 20        0.124640                3
# 17        0.124640                3
# 10        0.124640                3
# 21        0.123553                6
# 19        0.123337                6
# 4         0.123337                6
# 18        0.123265                6
# 16        0.122503               10
# 11        0.121493               11
# 5         0.121128               11
# 9         0.119787               13
# 8         0.118480               14
# 7         0.118480               14
# 6         0.117361               16
# 1         0.126890               17
# 15        0.137813               18
# 0         0.113054               19
# 14        0.139294               20
# 2         0.152749               21
# 13        0.201838               22
# 12        0.186485               23
# 3         0.166545               24

# %%
aboost_lb1_bparams = sorted_grid_aboost.iloc[0]['params']

# %% [markdown]
# ### AdaBoost - LB1 - Best Params

# %% [markdown]
# Fitted model

# %%
aboost_lb1_best = AdaBoostClassifier(random_state=13, **aboost_lb1_bparams)

# %%
aboost_lb1_best.fit(lb1_train, locs_lb1_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=4),
#                    learning_rate=2.0, n_estimators=75, random_state=13)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_pred, acc_score, aboost_predframe = model_predictions(aboost_lb1_best, lb1_test, locs_lb1_test)

# %%
aboost_acc = acc_meas(locs_lb1_test, locs_pred, return_vals=True)
# Out:
# accuracy score:    0.782312925170068
# f1 weighted score: 0.77401041008373
# f1 micro score:    0.782312925170068

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
aboost_predframe
# Out:
#                      Locality        PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak                Nemegt            0.400000
#          L2        Bayan Dzak                Nemegt            0.333333
#          L3        Bayan Dzak  [Bayan Dzak, Nemegt]            0.500000
# TS012    L1         Altan Uul             Altan Uul            0.897436
# TS020    L1            Nemegt                Nemegt            1.000000
# TS021    L1         Altan Uul             Altan Uul            0.514286
# TS022    L1         Altan Uul             Altan Uul            0.875000
#          L2         Altan Uul             Altan Uul            0.470588
# TS029    L1            Nemegt                Nemegt            0.981132
# TS030    L1    Tsagan Khushuu        Tsagan Khushuu            0.711538
#          L2    Tsagan Khushuu        Tsagan Khushuu            1.000000

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['aboost']['lb1'] = {'conf_mat' : confusion_matrix(locs_lb1_test, locs_pred, normalize='true', labels=lb_label_order), 'labels' : lb_label_acronym}

# %% [markdown]
# ---

# %% [markdown]
# ### AdaBoost - LB2 - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
aboost_params = {
    'algorithm' : ['SAMME', 'SAMME.R'],
    'n_estimators' : [50, 75],
    'learning_rate' : [1.0, 2.0],
    'estimator' : [DecisionTreeClassifier(max_depth=2), 
                   DecisionTreeClassifier(max_depth=3),
                   DecisionTreeClassifier(max_depth=4)]
}

# %%
aboost_grid = GridSearchCV(AdaBoostClassifier(random_state=13), param_grid=aboost_params, cv=3, n_jobs=-1)

# %%
aboost_grid.fit(lb2_train, locs_lb2_train)
# Out:
# GridSearchCV(cv=3, estimator=AdaBoostClassifier(random_state=13), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'estimator': [DecisionTreeClassifier(max_depth=2),
#                                        DecisionTreeClassifier(max_depth=3),
#                                        DecisionTreeClassifier(max_depth=4)],
#                          'learning_rate': [1.0, 2.0],
#                          'n_estimators': [50, 75]})

# %%
sorted_grid_aboost = grid_results_view(aboost_grid)

# %%
sorted_grid_aboost
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 19       0.262468      0.180906         0.010681        0.006331
# 18       0.247229      0.161360         0.012360        0.005576
# 15       0.382790      0.024152         0.015344        0.002400
# 14       0.270158      0.018611         0.013851        0.000472
# 13       0.405259      0.026702         0.020184        0.003682
# 2        0.241263      0.006259         0.015514        0.001412
# 1        0.353429      0.011241         0.021182        0.002394
# 21       0.325287      0.223991         0.009730        0.005865
# 20       0.248269      0.168225         0.009177        0.005182
# 5        0.298801      0.201464         0.013027        0.007054
# 22       0.218383      0.142942         0.008337        0.003858
# 17       0.298706      0.182048         0.010349        0.006141
# 4        0.202750      0.133644         0.009669        0.004715
# 23       0.263875      0.168918         0.008337        0.003774
# 8        0.237459      0.162250         0.011007        0.005664
# 9        0.343145      0.237333         0.013021        0.007084
# 0        0.238082      0.007090         0.013518        0.000006
# 7        0.314378      0.213237         0.013690        0.007603
# 6        0.200113      0.132044         0.010837        0.005634
# 10       0.217305      0.147323         0.009690        0.004749
# 11       0.326833      0.225113         0.011010        0.006175
# 3        0.358823      0.008885         0.019349        0.001659
# 16       0.211783      0.133557         0.010514        0.004610
# 12       0.254210      0.013049         0.013850        0.001537
#
#    param_algorithm                      param_estimator  param_learning_rate  \
# 19         SAMME.R  DecisionTreeClassifier(max_depth=3)                  2.0
# 18         SAMME.R  DecisionTreeClassifier(max_depth=3)                  2.0
# 15         SAMME.R  DecisionTreeClassifier(max_depth=2)                  2.0
# 14         SAMME.R  DecisionTreeClassifier(max_depth=2)                  2.0
# 13         SAMME.R  DecisionTreeClassifier(max_depth=2)                  1.0
# 2            SAMME  DecisionTreeClassifier(max_depth=2)                  2.0
# 1            SAMME  DecisionTreeClassifier(max_depth=2)                  1.0
# 21         SAMME.R  DecisionTreeClassifier(max_depth=4)                  1.0
# 20         SAMME.R  DecisionTreeClassifier(max_depth=4)                  1.0
# 5            SAMME  DecisionTreeClassifier(max_depth=3)                  1.0
# 22         SAMME.R  DecisionTreeClassifier(max_depth=4)                  2.0
# 17         SAMME.R  DecisionTreeClassifier(max_depth=3)                  1.0
# 4            SAMME  DecisionTreeClassifier(max_depth=3)                  1.0
# 23         SAMME.R  DecisionTreeClassifier(max_depth=4)                  2.0
# 8            SAMME  DecisionTreeClassifier(max_depth=4)                  1.0
# 9            SAMME  DecisionTreeClassifier(max_depth=4)                  1.0
# 0            SAMME  DecisionTreeClassifier(max_depth=2)                  1.0
# 7            SAMME  DecisionTreeClassifier(max_depth=3)                  2.0
# 6            SAMME  DecisionTreeClassifier(max_depth=3)                  2.0
# 10           SAMME  DecisionTreeClassifier(max_depth=4)                  2.0
# 11           SAMME  DecisionTreeClassifier(max_depth=4)                  2.0
# 3            SAMME  DecisionTreeClassifier(max_depth=2)                  2.0
# 16         SAMME.R  DecisionTreeClassifier(max_depth=3)                  1.0
# 12         SAMME.R  DecisionTreeClassifier(max_depth=2)                  1.0
#
#     param_n_estimators                                             params  \
# 19                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 18                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 15                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 14                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 13                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 2                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 1                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 21                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 20                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 5                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 22                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 17                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 4                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 23                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 8                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 9                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 0                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 7                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 6                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 10                  50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 11                  75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 3                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 16                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 12                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 19           0.670659           0.988024           1.000000         0.886228
# 18           0.670659           0.988024           1.000000         0.886228
# 15           0.676647           0.988024           0.987952         0.884207
# 14           0.664671           0.976048           0.987952         0.876223
# 13           0.664671           0.958084           0.987952         0.870235
# 2            0.622754           0.982036           0.993976         0.866255
# 1            0.514970           0.988024           1.000000         0.834331
# 21           0.491018           1.000000           1.000000         0.830339
# 20           0.491018           1.000000           1.000000         0.830339
# 5            0.491018           0.994012           1.000000         0.828343
# 22           0.491018           0.994012           1.000000         0.828343
# 17           0.514970           0.970060           1.000000         0.828343
# 4            0.491018           1.000000           0.993976         0.828331
# 23           0.491018           0.988024           1.000000         0.826347
# 8            0.491018           0.988024           1.000000         0.826347
# 9            0.491018           0.988024           1.000000         0.826347
# 0            0.485030           0.988024           1.000000         0.824351
# 7            0.491018           0.994012           0.963855         0.816295
# 6            0.491018           0.982036           0.969880         0.814311
# 10           0.491018           0.988024           0.957831         0.812291
# 11           0.491018           0.988024           0.957831         0.812291
# 3            0.574850           0.958084           0.885542         0.806159
# 16           0.514970           0.880240           1.000000         0.798403
# 12           0.664671           0.856287           0.765060         0.762006
#
#     std_test_score  rank_test_score
# 19        0.152509                1
# 18        0.152509                1
# 15        0.146768                3
# 14        0.149669                4
# 13        0.145867                5
# 2         0.172250                6
# 1         0.225875                7
# 21        0.239936                8
# 20        0.239936                8
# 5         0.238538               10
# 22        0.238538               10
# 17        0.221925               10
# 4         0.238529               13
# 23        0.237164               14
# 8         0.237164               14
# 9         0.237164               14
# 0         0.239986               17
# 7         0.230335               18
# 6         0.228657               19
# 10        0.227509               20
# 11        0.227509               20
# 3         0.166219               22
# 16        0.206295               23
# 12        0.078257               24

# %%
aboost_lb2_bparams = sorted_grid_aboost.iloc[0]['params']

# %% [markdown]
# ### AdaBoost - LB2 - Best Params

# %% [markdown]
# Fitted model

# %%
aboost_lb2_best = AdaBoostClassifier(random_state=13, **aboost_lb2_bparams)

# %%
aboost_lb2_best.fit(lb2_train, locs_lb2_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3),
#                    learning_rate=2.0, n_estimators=75, random_state=13)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_pred, acc_score, aboost_predframe = model_predictions(aboost_lb2_best, lb2_test, locs_lb2_test)

# %%
aboost_acc = acc_meas(locs_lb2_test, locs_pred, return_vals=True)
# Out:
# accuracy score:    0.842911877394636
# f1 weighted score: 0.8096086777627818
# f1 micro score:    0.842911877394636

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
aboost_predframe
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR006    L1        Bayan Dzak          Nemegt            0.000000
#          L2        Bayan Dzak          Nemegt            0.111111
#          L3        Bayan Dzak          Nemegt            0.125000
# TS012    L1         Altan Uul       Altan Uul            0.948718
# TS020    L1            Nemegt          Nemegt            0.976744
# TS021    L1         Altan Uul       Altan Uul            0.857143
# TS029    L1            Nemegt          Nemegt            1.000000
# TS030    L1    Tsagan Khushuu  Tsagan Khushuu            0.846154
#          L2    Tsagan Khushuu  Tsagan Khushuu            1.000000

# %%
lb2_results['Predict_aboost'] = lb2_results['Locality'] == locs_pred

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['aboost']['lb2'] = {'conf_mat' : confusion_matrix(locs_lb2_test, locs_pred, normalize='true', labels=lb_label_order), 'labels' : lb_label_acronym}

# %% [markdown]
# ---

# %% [markdown]
# ### AdaBoost - TB - Hyperparameters

# %% [markdown]
# Hyperparameters search for the algorithm and data subset

# %%
aboost_params = {
    'algorithm' : ['SAMME', 'SAMME.R'],
    'n_estimators' : [50, 75],
    'learning_rate' : [1.0, 2.0],
    'estimator' : [DecisionTreeClassifier(max_depth=2), 
                   DecisionTreeClassifier(max_depth=3),
                   DecisionTreeClassifier(max_depth=4)]
}

# %%
aboost_tb_grid = GridSearchCV(AdaBoostClassifier(estimator=DecisionTreeClassifier(), random_state=13), param_grid=aboost_params, cv=3, n_jobs=-1)

# %%
aboost_tb_grid.fit(tb_train, locs_tb_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(),
#                                           random_state=13),
#              n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'estimator': [DecisionTreeClassifier(max_depth=2),
#                                        DecisionTreeClassifier(max_depth=3),
#                                        DecisionTreeClassifier(max_depth=4)],
#                          'learning_rate': [1.0, 2.0],
#                          'n_estimators': [50, 75]})

# %%
sorted_grid_aboost_tb = grid_results_view(aboost_tb_grid)

# %%
sorted_grid_aboost_tb
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15       0.189623      0.037804         0.011180    1.306350e-03
# 12       0.172655      0.039057         0.010349    1.708995e-03
# 13       0.197141      0.039480         0.010692    2.120492e-04
# 14       0.164323      0.036637         0.007839    2.304029e-04
# 2        0.197772      0.005550         0.013698    6.153934e-04
# 0        0.177079      0.004320         0.013330    9.385697e-04
# 1        0.282738      0.018087         0.020658    9.521907e-04
# 3        0.276718      0.002162         0.022338    9.438086e-04
# 19       0.014841      0.003573         0.003000    1.403771e-06
# 18       0.011186      0.003289         0.003678    6.317025e-04
# 17       0.015361      0.004097         0.003173    8.515342e-04
# 16       0.018198      0.004015         0.003013    4.058461e-04
# 4        0.010669      0.003298         0.003001    6.257699e-07
# 5        0.011336      0.003682         0.003334    4.710894e-04
# 21       0.010668      0.001885         0.003669    4.714302e-04
# 20       0.008002      0.000002         0.003334    4.715390e-04
# 11       0.007334      0.000472         0.003001    9.199649e-07
# 10       0.007668      0.000471         0.003001    2.060172e-06
# 9        0.006947      0.000077         0.003001    3.371748e-07
# 8        0.007336      0.000471         0.003000    8.920806e-07
# 22       0.008668      0.000471         0.003002    1.512074e-06
# 23       0.008334      0.000471         0.002674    4.744243e-04
# 7        0.009670      0.001887         0.003000    2.247832e-07
# 6        0.009668      0.001886         0.005002    1.631903e-03
#
#    param_algorithm                      param_estimator  param_learning_rate  \
# 15         SAMME.R  DecisionTreeClassifier(max_depth=2)                  2.0
# 12         SAMME.R  DecisionTreeClassifier(max_depth=2)                  1.0
# 13         SAMME.R  DecisionTreeClassifier(max_depth=2)                  1.0
# 14         SAMME.R  DecisionTreeClassifier(max_depth=2)                  2.0
# 2            SAMME  DecisionTreeClassifier(max_depth=2)                  2.0
# 0            SAMME  DecisionTreeClassifier(max_depth=2)                  1.0
# 1            SAMME  DecisionTreeClassifier(max_depth=2)                  1.0
# 3            SAMME  DecisionTreeClassifier(max_depth=2)                  2.0
# 19         SAMME.R  DecisionTreeClassifier(max_depth=3)                  2.0
# 18         SAMME.R  DecisionTreeClassifier(max_depth=3)                  2.0
# 17         SAMME.R  DecisionTreeClassifier(max_depth=3)                  1.0
# 16         SAMME.R  DecisionTreeClassifier(max_depth=3)                  1.0
# 4            SAMME  DecisionTreeClassifier(max_depth=3)                  1.0
# 5            SAMME  DecisionTreeClassifier(max_depth=3)                  1.0
# 21         SAMME.R  DecisionTreeClassifier(max_depth=4)                  1.0
# 20         SAMME.R  DecisionTreeClassifier(max_depth=4)                  1.0
# 11           SAMME  DecisionTreeClassifier(max_depth=4)                  2.0
# 10           SAMME  DecisionTreeClassifier(max_depth=4)                  2.0
# 9            SAMME  DecisionTreeClassifier(max_depth=4)                  1.0
# 8            SAMME  DecisionTreeClassifier(max_depth=4)                  1.0
# 22         SAMME.R  DecisionTreeClassifier(max_depth=4)                  2.0
# 23         SAMME.R  DecisionTreeClassifier(max_depth=4)                  2.0
# 7            SAMME  DecisionTreeClassifier(max_depth=3)                  2.0
# 6            SAMME  DecisionTreeClassifier(max_depth=3)                  2.0
#
#     param_n_estimators                                             params  \
# 15                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 12                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 13                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 14                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 2                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 0                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 1                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 3                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 19                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 18                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 17                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 16                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 4                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 5                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 21                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 20                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 11                  75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 10                  50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 9                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 8                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 22                  50  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 23                  75  {'algorithm': 'SAMME.R', 'estimator': Decision...
# 7                   75  {'algorithm': 'SAMME', 'estimator': DecisionTr...
# 6                   50  {'algorithm': 'SAMME', 'estimator': DecisionTr...
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 15           0.905882           0.988095           0.880952         0.924977
# 12           0.905882           0.988095           0.869048         0.921008
# 13           0.905882           0.988095           0.857143         0.917040
# 14           0.905882           0.976190           0.869048         0.917040
# 2            0.917647           1.000000           0.821429         0.913025
# 0            0.894118           0.988095           0.797619         0.893277
# 1            0.894118           0.988095           0.785714         0.889309
# 3            0.835294           1.000000           0.809524         0.881606
# 19           0.905882           0.964286           0.714286         0.861485
# 18           0.905882           0.964286           0.714286         0.861485
# 17           0.905882           0.964286           0.714286         0.861485
# 16           0.905882           0.964286           0.714286         0.861485
# 4            0.952941           0.964286           0.654762         0.857330
# 5            0.952941           0.964286           0.654762         0.857330
# 21           0.835294           0.964286           0.750000         0.849860
# 20           0.835294           0.964286           0.750000         0.849860
# 11           0.835294           0.964286           0.750000         0.849860
# 10           0.835294           0.964286           0.750000         0.849860
# 9            0.835294           0.964286           0.750000         0.849860
# 8            0.835294           0.964286           0.750000         0.849860
# 22           0.835294           0.964286           0.750000         0.849860
# 23           0.835294           0.964286           0.750000         0.849860
# 7            0.870588           0.964286           0.654762         0.829879
# 6            0.870588           0.964286           0.654762         0.829879
#
#     std_test_score  rank_test_score
# 15        0.045777                1
# 12        0.049764                2
# 13        0.054040                3
# 14        0.044447                3
# 2         0.072975                5
# 0         0.077764                6
# 1         0.082692                7
# 3         0.084376                8
# 19        0.106781                9
# 18        0.106781                9
# 17        0.106781                9
# 16        0.106781                9
# 4         0.143312               13
# 5         0.143312               13
# 21        0.088086               15
# 20        0.088086               15
# 11        0.088086               15
# 10        0.088086               15
# 9         0.088086               15
# 8         0.088086               15
# 22        0.088086               15
# 23        0.088086               15
# 7         0.129600               23
# 6         0.129600               23

# %%
aboost_tb_bparams = sorted_grid_aboost_tb.iloc[0]['params']

# %% [markdown]
# ### AdaBoost - TB - Best Params

# %% [markdown]
# Fitted model

# %%
aboost_tb_best = AdaBoostClassifier(random_state=13, **aboost_tb_bparams)

# %%
aboost_tb_best.fit(tb_train, locs_tb_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=2),
#                    learning_rate=2.0, n_estimators=75, random_state=13)

# %% [markdown]
# Prediction and accuracy measures

# %%
locs_tb_pred, acc_score, aboost_predframe = model_predictions(aboost_tb_best, tb_test, locs_tb_test)

# %%
acc_score
# Out:
# 0.32098765432098764

# %%
aboost_acc = acc_meas(locs_tb_test, locs_tb_pred, return_vals=True)
# Out:
# accuracy score:    0.32098765432098764
# f1 weighted score: 0.33188222312159926
# f1 micro score:    0.32098765432098764

# %% [markdown]
# Prediction for the spots in the whole sample

# %%
aboost_predframe
# Out:
#                      Locality  PredictionMode  PredictionAccuracy
# SampleID Line
# PR001    L1          Toogreek        Toogreek            1.000000
# SF003    L1         Altan Uul          Nemegt            0.000000
#          L2         Altan Uul  Tsagan Khushuu            0.000000
#          L3         Altan Uul  Tsagan Khushuu            0.000000
#          L4         Altan Uul          Nemegt            0.000000
# TF028    L1            Nemegt          Nemegt            1.000000
#          L2            Nemegt          Nemegt            1.000000
#          L3            Nemegt       Altan Uul            0.133333
#          L4            Nemegt       Altan Uul            0.045455
# TS027    L1    Tsagan Khushuu          Nemegt            0.000000
#          L2    Tsagan Khushuu          Nemegt            0.200000
#          L3    Tsagan Khushuu          Nemegt            0.000000

# %% [markdown]
# Add the data to the confusion matrices dictionary

# %%
conf_mat_dict['aboost']['tb'] = {'conf_mat' : confusion_matrix(locs_tb_test, locs_tb_pred, normalize='true', labels=tb_label_order), 'labels' : tb_label_acronym}

# %% [markdown]
# ---

# %%
spot_info.groupby('SampleID')['Locality'].max()
# Out:
# SampleID
# PR001          Toogreek
# PR002          Toogreek
# PR003        Bayan Dzak
# PR006        Bayan Dzak
# SF001            Nemegt
# SF002         Altan Uul
# SF003         Altan Uul
# TF006            Nemegt
# TF028            Nemegt
# TF029    Tsagan Khushuu
# TS011         Altan Uul
# TS012         Altan Uul
# TS013            Nemegt
# TS015         Altan Uul
# TS016    Tsagan Khushuu
# TS017    Tsagan Khushuu
# TS018    Tsagan Khushuu
# TS020            Nemegt
# TS021         Altan Uul
# TS022         Altan Uul
# TS023            Nemegt
# TS024            Nemegt
# TS025            Nemegt
# TS026            Nemegt
# TS027    Tsagan Khushuu
# TS029            Nemegt
# TS030    Tsagan Khushuu
# TS031         Altan Uul
# Name: Locality, dtype: object

# %% [markdown]
# # Features Selection for elements

# %%
sel_logreg = SelectFromModel(logreg_lb2_best, prefit=True, threshold='mean')
sel_forest = SelectFromModel(forest_lb2_best, prefit=True, threshold='mean')
sel_aboost = SelectFromModel(aboost_lb2_best, prefit=True, threshold='mean')
sel_xboost = SelectFromModel(xboost_lb2_best, prefit=True, threshold='mean')

# %%
sel_alr_train = {}
sel_alr_train['logreg'] = sel_logreg.fit_transform(lb2_train, locs_lb2_train)
sel_alr_train['forest'] = sel_forest.fit_transform(lb2_train, locs_lb2_train)
sel_alr_train['aboost'] = sel_aboost.fit_transform(lb2_train, locs_lb2_train)
sel_alr_train['xboost'] = sel_xboost.fit_transform(lb2_train, locs_lb2_train)

# %%
name_selections = dict(zip(['logreg', 'forest', 'aboost', 'xboost'], [sel_logreg, sel_forest, sel_aboost, sel_xboost]))

# %%
for name, sel in name_selections.items():
    print('{}:'.format(name), sel.get_feature_names_out())
# Out:
# logreg: ['V' 'Mn' 'Fe' 'Zn' 'Y' 'U']
# forest: ['Sr' 'Y' 'Ba' 'La' 'Pr' 'Dy' 'Ho' 'Lu' 'Th' 'U']
# aboost: ['Mn' 'Zn' 'Sr' 'Y' 'Ba' 'Yb' 'Lu' 'Th' 'U']
# xboost: ['Y' 'Ba' 'Nd' 'Sm' 'U']

# %%
feats_importances = models_feats(logreg=logreg_lb2_best, forest=forest_lb2_best, aboost=aboost_lb2_best, xboost=xboost_lb2_best)

# %%
model_names = ['logreg', 'forest', 'aboost', 'xboost']

# %%
for name in model_names:
    fimp = feats_importances[name].sort_values(ascending=False)
    imp = 0
    el_list = []
    for element, importance in fimp.items():
        el_list.append(element)
        imp += importance
        if imp > .85:
            break
    
    print(name)
    print(el_list, '   - len: ', len(el_list))
    print('TOTAL: ', imp)
    print()
# Out:
# logreg
# ['U', 'Zn', 'V', 'Y', 'Fe', 'Mn', 'La', 'Ce', 'Th', 'Ga', 'Yb', 'Dy', 'Sr', 'Ba', 'Cu', 'Lu']    - len:  16
# TOTAL:  0.8555860587787942
#
# forest
# ['Th', 'Ba', 'Sr', 'U', 'Y', 'La', 'Pr', 'Dy', 'Lu', 'Ho', 'Sm', 'Tm', 'V', 'Er', 'Eu', 'Nd', 'Tb', 'Gd']    - len:  18
# TOTAL:  0.8522593171881411
#
# aboost
# ['Ba', 'Sr', 'Lu', 'Th', 'Zn', 'Yb', 'U', 'Mn', 'Y']    - len:  9
# TOTAL:  0.8510143729231677
#
# xboost
# ['Nd', 'Ba', 'U', 'Sm', 'Y', 'Ho', 'Yb', 'Mn', 'Th']    - len:  9
# TOTAL:  0.8642644137144089

# %%
feats_importances.sort_values('forest', ascending=False)
# Out:
#       logreg    forest        aboost    xboost
# Th  0.034412  0.115246  9.861220e-02  0.027238
# Ba  0.024111  0.079033  1.433792e-01  0.238363
# Sr  0.025788  0.062629  1.380359e-01  0.015854
# U   0.149540  0.058722  7.559203e-02  0.105390
# Y   0.065949  0.054910  4.194488e-02  0.037289
# La  0.034932  0.050195  5.097169e-05  0.000000
# Pr  0.010621  0.041971  4.678431e-05  0.005326
# Dy  0.025807  0.039600  1.360757e-02  0.000000
# Lu  0.021403  0.038790  1.219453e-01  0.003859
# Ho  0.012797  0.038314  6.288855e-03  0.036580
# Sm  0.011515  0.035764  1.113272e-03  0.082074
# Tm  0.014264  0.035664  3.646332e-02  0.000000
# V   0.103656  0.034926  3.543598e-02  0.012562
# Er  0.020397  0.034164  2.989435e-03  0.001771
# Eu  0.013282  0.033941  1.044540e-02  0.013608
# Nd  0.012921  0.033892  2.084234e-04  0.271742
# Tb  0.016946  0.032383  2.477865e-04  0.000253
# Gd  0.011374  0.032114  4.001180e-13  0.011618
# Mn  0.058511  0.031757  5.072517e-02  0.032527
# Yb  0.027101  0.030469  8.934673e-02  0.033063
# Hf  0.014561  0.028944  3.086635e-03  0.004692
# Ce  0.034503  0.019539  3.507345e-04  0.013620
# Fe  0.058868  0.010306  9.771320e-03  0.020451
# Ga  0.033607  0.008990  2.765111e-11  0.003587
# Zn  0.134769  0.007227  9.143294e-02  0.004216
# Rb  0.005735  0.005728  2.560538e-02  0.014393
# Cu  0.022628  0.004781  3.273750e-03  0.009925

# %% [markdown]
# # Plots

# %%
sns.set_theme(palette='colorblind', style='ticks')

# %% [markdown]
# ## Confusion matrices

# %%
algorithms = ['logreg', 'forest', 'xboost', 'aboost']
subsets = ['lb1', 'lb2', 'tb']

# %%
titles = dict(zip(algorithms, ['Logistic regression', 'Random forest', 'XGBoost', 'AdaBoost']))

# %%
fig = plt.figure(layout="constrained", figsize=(6, 8))
subfigs = fig.subfigures(4, 1)

subfig_dict = dict(zip(algorithms, subfigs))
axes_dict = {}
letters = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L']
letter_counter = 0

for algorithm, subfig in subfig_dict.items():
    axs = subfig.subplots(1, 3)
    axes_dict[algorithm] = axs
    for num, subset in enumerate(subsets):
        conf_mat = conf_mat_dict[algorithm][subset]['conf_mat'].round(2)
        labels = conf_mat_dict[algorithm][subset]['labels']
        sns.heatmap(conf_mat, xticklabels=labels, yticklabels=labels, cbar=False, ax=axs[num], vmin=0, vmax=1, cmap='coolwarm', annot=True, square=True, annot_kws={'size':'small'})
        #axs[num].text(-0.1, 1, letters[letter_counter+num], size='medium', transform=axs[num].transAxes, ha='left', va='bottom')
        #title = "Subset " + subset.upper()
        # axs[num].set_title(letters[letter_counter+num], size='medium', weight='bold', loc='left')
        axs[num].annotate(letters[letter_counter+num], (-.1, 1.05), xycoords='axes fraction', size='medium', weight='bold')
    letter_counter += 3
    subfig.supylabel(titles[algorithm], weight='bold')

fig.text(x=0.190, y=1.0, s='LB1', size='large', weight='bold')
fig.text(x=0.505, y=1.0, s='LB2', size='large', weight='bold')
fig.text(x=0.835, y=1.0, s='TB', size='large', weight='bold')
# Out:
# Text(0.835, 1.0, 'TB')

# %%
fig.savefig('Plots/ConfusionMatricesHeatmaps.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Boxplots

# %%
other_elems = ['V', 'Mn', 'Fe', 'Cu', 'Zn', 'Ga', 'Rb', 'Sr', 'Ba', 'Hf', 'Th', 'U']
ree = ['La', 'Ce', 'Pr', 'Nd', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Y', 'Er', 'Tm', 'Yb', 'Lu']

# %%
ppm_long_other = ppm_long[ppm_long.Element.isin(other_elems)]
ppm_long_ree = ppm_long[ppm_long.Element.isin(ree)]

# %% [markdown]
# ### Other elements

# %%
cp = sns.catplot(
    ppm_long_other, 
    x='Locality', 
    y='PPM', 
    col='Element', 
    col_wrap=3, 
    palette='colorblind', 
    log_scale=True, 
    hue='Locality',
    sharey=False,
    kind='box',
    height=3,
    aspect=1
)
[plt.setp(ax.get_xticklabels(), rotation=90) for ax in cp.axes.flat]
cp.set(xlabel=None)
cp.set_titles('{col_name}')

# %%
cp.savefig('Plots/boxplots - non-REEY.jpg', dpi=300)

# %% [markdown]
# ### REEY

# %%
cp = sns.catplot(
    ppm_long_ree, 
    x='Locality', 
    y='PPM', 
    col='Element', 
    col_wrap=3, 
    palette='colorblind', 
    log_scale=True, 
    hue='Locality',
    sharey=False,
    kind='box',
    height=3,
    aspect=1,
    col_order = ree
)
[plt.setp(ax.get_xticklabels(), rotation=90) for ax in cp.axes.flat]
cp.set(xlabel=None)
cp.set_titles('{col_name}')

# %%
cp.savefig('Plots/boxplots - REEY.jpg', dpi=300)

# %% [markdown]
# ###  Ba and Sr

# %%
basr = ppm.loc[:, ['Ba', 'Sr']].merge(spot_info, left_index=True, right_index=True)

# %%
basr_long = basr.melt(id_vars=spot_info.columns, ignore_index=False, var_name='Var', value_name='Val')

# %%
cp = sns.catplot(basr_long, y='Val', x='Locality', hue='Locality', log_scale=True, kind='box', col='Var', sharey=False, aspect=1.25)
cp.set_titles('{col_name}')
cp.set(xlabel='', ylabel='')

# %%
cp.savefig('Plots/Sr and Ba contents.jpg', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.boxplot(data=basr, x='Locality', y=basr.Sr/basr.Ba, hue='Locality', log_scale=True, ax=ax)
ax.set(xlabel='', ylabel='Sr/Ba')
# Out:
# [Text(0.5, 0, ''), Text(0, 0.5, 'Sr/Ba')]

# %%
fig.savefig('Plots/Sr-Ba ratio.jpg', dpi=300)

# %% [markdown]
# ## HREE

# %%
hree = ppm.loc[:, ['Y', 'Tm', 'Yb', 'Ho']].merge(spot_info, left_index=True, right_index=True)

# %%
hree_long = hree.melt(id_vars=spot_info.columns, ignore_index=False, var_name='Var', value_name='Val')

# %%
cp = sns.catplot(hree_long, y='Val', x='Locality', hue='Locality', log_scale=True, kind='box', col='Var', col_wrap=2, sharey=False, aspect=1.25)
cp.set_titles('{col_name}')
cp.set(xlabel='', ylabel='')

# %%
fig.savefig('Plots/HREE boxplots.jpg', dpi=300)

# %% [markdown]
# ## Mn and Fe

# %%
metox = ppm.loc[:, ['Mn', 'Fe']].merge(spot_info, left_index=True, right_index=True)

# %%
metox_long = metox.melt(id_vars=spot_info.columns, ignore_index=False, var_name='Var', value_name='Val')

# %%
cp = sns.catplot(metox_long, y='Val', x='Locality', hue='Locality', log_scale=True, kind='box', col='Var', sharey=False, aspect=1.25)
cp.set_titles('{col_name}')
cp.set(xlabel='', ylabel='')

# %%
fig.savefig('Plots/Fe and Mn boxplots.jpg', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.boxplot(data=metox, x='Locality', y=metox.Fe/metox.Mn, hue='Locality', log_scale=True, ax=ax)
ax.set(xlabel='', ylabel='Fe/Mn')
# Out:
# [Text(0.5, 0, ''), Text(0, 0.5, 'Fe/Mn')]

# %%
fig.savefig('Plots/Mn-Fe ratio.jpg', dpi=300)

# %% [markdown]
# ## U and Th

# %%
uth = ppm.loc[:, ['U', 'Th']].merge(spot_info, left_index=True, right_index=True)

# %%
uth_long = uth.melt(id_vars=spot_info.columns, ignore_index=False, var_name='Var', value_name='Val')

# %%
cp = sns.catplot(uth_long, y='Val', x='Locality', hue='Locality', log_scale=True, kind='box', col='Var', sharey=False, aspect=1.25)
cp.set_titles('{col_name}')
cp.set(xlabel='', ylabel='')

# %%
fig.savefig('Plots/U and Th boxplots.jpg', dpi=300)

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.boxplot(data=basr, x='Locality', y=uth.Th/uth.U, hue='Locality', log_scale=True, ax=ax)
ax.set(xlabel='', ylabel='Th/U')
# Out:
# [Text(0.5, 0, ''), Text(0, 0.5, 'Th/U')]

# %%
fig.savefig('Plots/Th-U ratio.jpg', dpi=300)

# %%
selected_others = ppm.loc[:, ['Ba', 'Sr', 'Mn', 'Fe', 'U', 'Th']].merge(spot_info, left_index=True, right_index=True)

# %%
selected_hree = ppm.loc[:, ['Ho', 'Y', 'Tm', 'Yb']].merge(spot_info, left_index=True, right_index=True)

# %%
selected_others = selected_others.melt(id_vars=spot_info.columns, ignore_index=False, var_name='Var', value_name='Val')

# %%
selected_hree = selected_hree.melt(id_vars=spot_info.columns, ignore_index=False, var_name='Var', value_name='Val')

# %%
cp = sns.catplot(selected_hree, y='Val', x='Locality', hue='Locality', log_scale=True, kind='box', col='Var', col_wrap=2, sharey=False, aspect=1.25)
cp.set_titles('{col_name}')
cp.set(xlabel='', ylabel='')

# %%
cp.savefig('Plots/HREE boxplots.jpg', dpi=300)

# %%
cp = sns.catplot(selected_others, y='Val', x='Locality', hue='Locality', log_scale=True, kind='box', col='Var', col_wrap=2, sharey=False, aspect=1.25)
cp.set_titles('{col_name}')
cp.set(xlabel='', ylabel='')

# %%
cp.savefig('Plots/Other elements boxplots.jpg', dpi=300)

# %%
ppm_fullframe = ppm.merge(spot_info, left_index=True, right_index=True)

# %%
ppmData = ppm_fullframe.reset_index()
ppmData['SampleLine'] = ppmData.SampleID + '-' + ppmData.Line

# %%
ppmData.columns
# Out:
# Index(['SampleID', 'Line', 'Spot', 'SpotID', 'Ca', 'V', 'Mn', 'Fe', 'Cu', 'Zn',
#        'Ga', 'Rb', 'Sr', 'Y', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Sm', 'Eu', 'Gd',
#        'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Th', 'U', 'SpecimenID',
#        'Genus', 'Locality', 'Bone', 'tissueType', 'mmDist', 'maxDist',
#        'profilePerc', 'Other comm', 'SampleLine'],
#       dtype='object')

# %%
ppmData = ppmData.loc[:, ['SampleID', 'Line', 'Spot', 'SpotID', 'SampleLine', 
                          'V', 'Mn', 'Fe', 'Cu', 'Zn', 'Ga', 'Rb', 'Sr', 'Y',
                          'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Sm', 'Eu', 'Gd', 'Tb',
                          'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Th', 'U', 
                          'SpecimenID', 'Genus', 'Locality', 'Bone', 'tissueType', 
                          'mmDist', 'profilePerc']]

# %%
elements_analyzed = ['V', 'Mn', 'Fe', 'Cu', 'Zn', 'Ga', 'Rb', 'Sr', 'Y', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Th', 'U']

# %% [markdown]
# # Profiles of all elements

# %%
locs_order = 'Nemegt', 'Altan Uul', 'Tsagan Khushuu', 'Toogreek', 'Bayan Dzak'

# %%
locs_array = np.array([['Nemegt', 'Altan Uul', 'Tsagan Khushuu'], ['Toogreek', 'Bayan Dzak', None]])

# %% [markdown]
# Code below is to generate interactive plotly plot with profiles of all elements. The notebook takes a lot of time to process the code when it is active, so it remains inactive.

# %%
def count_fig_axes(plotly_fig, x=True, y=True):

    answer = {}
    
    if x:
        xaxes = 0
        for kword in plotly_fig.layout:
            if kword.startswith('xaxis'):
                xaxes += 1
        answer['x'] = xaxes
    if y:
        yaxes = 0
        for kword in plotly_fig.layout:
            if kword.startswith('yaxis'):
                yaxes += 1
        answer['y'] = yaxes
    return answer

#%% Element profiles

# create the figure with subplots for 5 localities (6th plot is empty)
plotly_fig = make_subplots(rows=2, cols=3, shared_xaxes='all', shared_yaxes='all', subplot_titles=locs_order, vertical_spacing=0.1, horizontal_spacing=0.05)

# code for the buttons of the element selection
steps_dict = {}
steps_back = 0
visibility = True

for element in elements_analyzed:
    ### iterate over elements
    ### from the table select only the columns with:
    ###  - an element of interest
    ###  - distance - that is, X-data
    ###  - sample and spot information (sample ID, spot no, profile, specimen)
    ###  - bone and locality
    frame = ppmData.loc[:, [element, 'SampleID', 'SpecimenID', 'mmDist', 'Bone', 'Locality', 'SampleLine', 'Spot']]
    frame.dropna(subset=element, inplace=True)
    step_vals = []

    for loc in locs_array.flatten():
        ### iteration over localitites
        
        if loc: # if locality is not NONE
            row, col = np.where(locs_array == loc)
            row, col = row[0] + 1, col[0] + 1
            
            frame_loc = frame[frame.Locality == loc]
            slines = frame_loc['SampleLine'].unique()

                        
            for sline in slines:
                ### iteration over sample-lines/profiles
                ### each profile is a trace added to the relevant plot
                frame_sline = frame_loc[frame_loc.SampleLine == sline]
 
                plotly_fig.add_trace(
                    go.Scatter(
                        visible=visibility,
                        mode='lines+markers',
                        x=frame_sline['mmDist'],
                        y=frame_sline[element],
                        text=[element] * len(frame_sline), # to ensure that each spot on the plot has `text` value equal to the name of an element
                        name=sline,
                        customdata=frame_sline[['SampleID', 'SampleLine', 'Spot', 'Bone', 'SpecimenID']]
                    ),
                    row=row,
                    col=col
                )
                step_vals.append(True)
        else: # if locality IS NONE
            continue
    
    # the code below is to ensure that the buttons related to the elements work properly and display selected element
    # the logic is to create a list of boolean values, where all values are FALSE,
    # except for the ones referring to the element selected from the button
    this_step = [False] * steps_back + step_vals + [False] * (1508 - (steps_back + len(step_vals))) # steps_back = elements_analyzed (that is - features) * no of samplelines (53)
    steps_dict[element] = this_step
    steps_back += len(step_vals)
    visibility = False



### code for selection of the elements
buttons = []

for elem, active_traces in steps_dict.items():
    button = dict(
        label=str(elem),
        method="restyle",
        args=["visible", active_traces]
    )
    buttons.append(button)

# count axes and set data for buttons switching between linear and logarithmic scale
ax_num = count_fig_axes(plotly_fig, x=False)['y'] - 1
args_lin = dict(zip([f'yaxis.type' if i == 0 else f'yaxis{i + 1}.type'for i in range(ax_num)], ['linear'] * ax_num))
args_log = dict(zip([f'yaxis.type' if i == 0 else f'yaxis{i + 1}.type'for i in range(ax_num)], ['log'] * ax_num))

### buttons to switch between linear and logarithmic scale
plotly_fig.update_layout(
    updatemenus=[
        dict(
            type='buttons', 
            buttons=buttons,
            showactive=True,
            x=-0.05,
            y=1,
            xanchor="center",
            yanchor="top",
            direction='down'),
        {
        'type' : 'buttons',
        'buttons' : [{
            'label' : 'Linear scale',
            'method' : 'relayout',
            'args' : [args_lin]
        },
        {
            'label' : 'Logscale',
            'method' : 'relayout',
            'args' : [args_log]
        }],
            'direction' : 'right',
            'x' : 0,
            'y' : 1.075,
            'xanchor' : 'left',
            'yanchor' : 'top'
    }
        
        ],
    width=1800,
    height=1200, 
    showlegend=False
)

                         
plotly_fig.update_traces(hovertemplate=
                         '<b>%{customdata[0]}</b><br>' +
                         '<i>%{customdata[1]}-%{customdata[2]}</i><br>' +
                         '<i>%{customdata[4]}</i><br>' +
                         'Bone: <b>%{customdata[3]}</b><br>' + 
                         'Distance: <b>%{x} mm</b><br>' + 
                         '%{text}: ' +'<b>%{y}</b>'+
                         "<extra></extra>")

plotly_fig.update_xaxes(range=(0, 40))
plotly_fig.update_yaxes(range=(-300, 5300))
plotly_fig.write_html('Plots\\Element profiles.html', default_width=2100, default_height=1400)

# %%
ppmData.columns
# Out:
# Index(['SampleID', 'Line', 'Spot', 'SpotID', 'SampleLine', 'V', 'Mn', 'Fe',
#        'Cu', 'Zn', 'Ga', 'Rb', 'Sr', 'Y', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Sm',
#        'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Th', 'U',
#        'SpecimenID', 'Genus', 'Locality', 'Bone', 'tissueType', 'mmDist',
#        'profilePerc'],
#       dtype='object')

# %%
df = ppm.merge(spot_info, left_index=True, right_index=True)

# %%
df['Profile'] = df.index.get_level_values(0) + '-' + df.index.get_level_values(1)

# %%
ppmData.sort_values(['Locality', 'SampleID', 'Line', 'mmDist'], inplace=True)

# %%
all_profiles = PdfPages('All profiles.pdf')

for element in elements_analyzed:
    g = sns.relplot(df, 
                    x='mmDist',
                    y=element,
                    hue='Profile',
                    col='Locality',
                    col_wrap=3,
                    facet_kws=dict(sharex=False, sharey=False),
                    style='Profile').set(yscale='log', ylabel='Distance [mm]')
    
    sns.move_legend(g, loc='center left', ncols=3, title='Profile', bbox_to_anchor=(0.73, 0.28), fontsize='small')
    
    fig = g.figure
    fig.set_constrained_layout(True)
    
    all_profiles.savefig(fig)
    plt.close()
    
all_profiles.close()
